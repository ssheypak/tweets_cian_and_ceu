# %% [markdown]
# ### Загружаем текст и ищем, по какому символу разбить

# %%
with open("data/reviews.txt", "r") as file:
    text = file.read()
    
text = text.lstrip("INTELLIGENCE\n\n")

# %%
tokens = text.split()

# %%
from collections import Counter
c = Counter(tokens)
c.most_common(10)
# Out:
# [('1.215', 1244),
#  ('и', 640),
#  ('не', 636),
#  ('1.214.1', 484),
#  ('в', 432),
#  ('сдавать', 430),
#  ('кому', 405),
#  ('на', 259),
#  ('что', 257),
#  ('только', 234)]

# %% [markdown]
# Разбиваем

# %%
import re
reviews = [x.strip().lower() for x in re.split("1.215|1.214.1", text)]

# %%
reviews[:5]
# Out:
# ['дискриминация собственников жилья. русофобы!!!',
#  'ужас из за убранной возможности указывать национальность, костре приехали и чуть не избили нерусские за то что я им отказал! удаляю навсегда!!!!',
#  'я буду сдавать квартиру,кому хочу и это буду славяне!🙋🏼\u200d♂️☀️ приложение ужасное,и проведайте там свои акции компании,как вы играете в толерастов и акции идут в упадок…',
#  'спасибо циан! придется разговаривать с людьми, плохо знающими русский язык, которые хотят заселиться всем табуном в мою квартиру. спасибо, вы сами же и усложнили поиск квартиры иностранцам ближнего зарубежья, теперь им придется побегать и потрать кучу времени на поиск человека, которому безразлично на то, кому сдавать квартиру',
#  'почему решать кому-то кому я хочу сдавать квартиру? почему решаете вы, что делать с моей собственностью, захочу только собакам сдавать буду, а захочу бригаду строителей, это не правила а бред.']

# %%
from collections import defaultdict
import matplotlib.pyplot as plt
import math
import numpy as np

# %%
plt.figure(figsize=(16, 8))
plt.hist([len(x) for x in reviews], bins=np.arange(0, 1000, 20), rwidth=1)
plt.grid()
plt.title("Количества в букв в отзывах")
plt.xticks(np.arange(0, 1000, 20), rotation=90)
plt.show()

# %% [markdown]
# ### Пробуем разбить отзывы на предложения.

# %%
import nltk
# nltk.download("punkt")

# %%
from nltk.tokenize import sent_tokenize

# %%
len_sorted_reviews = sorted(reviews, key=lambda x: len(x), reverse=True)

# %%
longest_review = len_sorted_reviews[1]

# %%
len_sorted_reviews[-10:]
# Out:
# ['р русофобы',
#  'удаляю дно',
#  'пока пока',
#  'ок ужасно',
#  '4рки пааа',
#  '1 шляпа',
#  'ш глупо',
#  '👍👍👍 👍👍👍',
#  ':( :(',
#  '👎🏼 👎🏼']

# %%
longest_review
# Out:
# 'про ксенофобию, славян и не только. итак, однозначно плохо и убого то, что теперь нельзя писать легендарную фразу. я как не сдавал, так и не стану сдавать им квартиру - не хочу и всё, и никакая левачка из вышки не может и не имеет никакого права заставить меня этого не делать. зато они теперь будут тратить время зря на звонки и беседы, ведь им я не сдам потому что не хочу и это моё решение. зато посмотрите как забавно радуются (обратите внимание - подавляющее большинство женщины) левачки этому запрету. они рады лишний раз заткнуть нам рот. они слабы и убоги, и ничего у них не получится.а я как сдавал только славянам, так и буду продолжать это делать. я живу в стране где 80% населения - русские. и правила здесь должны устанавливать русские. на кавказе главные кавказцы, с этим никто не поспорит: в чечне - чеченцы, в дагестане - дагестанцы. и никого не смущает что в том же дагестане, между прочим, живут староверы. но когда речь заходит о россии - поднимаются невероятные вопли. все кроме нас могут быть хозяевами своей земли, и это неправильно. так же работает ваша любимая демократия - власть большинства. вот и примите власть 80% населения рф и не спорьте с ней. либо возвращайтесь в свои солнечные великие аулы.'

# %%
sent_tokenize(longest_review.replace(".", "."))
# Out:
# ['про ксенофобию, славян и не только.',
#  'итак, однозначно плохо и убого то, что теперь нельзя писать легендарную фразу.',
#  'я как не сдавал, так и не стану сдавать им квартиру - не хочу и всё, и никакая левачка из вышки не может и не имеет никакого права заставить меня этого не делать.',
#  'зато они теперь будут тратить время зря на звонки и беседы, ведь им я не сдам потому что не хочу и это моё решение.',
#  'зато посмотрите как забавно радуются (обратите внимание - подавляющее большинство женщины) левачки этому запрету.',
#  'они рады лишний раз заткнуть нам рот.',
#  'они слабы и убоги, и ничего у них не получится.а я как сдавал только славянам, так и буду продолжать это делать.',
#  'я живу в стране где 80% населения - русские.',
#  'и правила здесь должны устанавливать русские.',
#  'на кавказе главные кавказцы, с этим никто не поспорит: в чечне - чеченцы, в дагестане - дагестанцы.',
#  'и никого не смущает что в том же дагестане, между прочим, живут староверы.',
#  'но когда речь заходит о россии - поднимаются невероятные вопли.',
#  'все кроме нас могут быть хозяевами своей земли, и это неправильно.',
#  'так же работает ваша любимая демократия - власть большинства.',
#  'вот и примите власть 80% населения рф и не спорьте с ней.',
#  'либо возвращайтесь в свои солнечные великие аулы.']

# %%
sent_tokenize(longest_review.replace(".", " . "))
# Out:
# ['про ксенофобию, славян и не только .',
#  'итак, однозначно плохо и убого то, что теперь нельзя писать легендарную фразу .',
#  'я как не сдавал, так и не стану сдавать им квартиру - не хочу и всё, и никакая левачка из вышки не может и не имеет никакого права заставить меня этого не делать .',
#  'зато они теперь будут тратить время зря на звонки и беседы, ведь им я не сдам потому что не хочу и это моё решение .',
#  'зато посмотрите как забавно радуются (обратите внимание - подавляющее большинство женщины) левачки этому запрету .',
#  'они рады лишний раз заткнуть нам рот .',
#  'они слабы и убоги, и ничего у них не получится .',
#  'а я как сдавал только славянам, так и буду продолжать это делать .',
#  'я живу в стране где 80% населения - русские .',
#  'и правила здесь должны устанавливать русские .',
#  'на кавказе главные кавказцы, с этим никто не поспорит: в чечне - чеченцы, в дагестане - дагестанцы .',
#  'и никого не смущает что в том же дагестане, между прочим, живут староверы .',
#  'но когда речь заходит о россии - поднимаются невероятные вопли .',
#  'все кроме нас могут быть хозяевами своей земли, и это неправильно .',
#  'так же работает ваша любимая демократия - власть большинства .',
#  'вот и примите власть 80% населения рф и не спорьте с ней .',
#  'либо возвращайтесь в свои солнечные великие аулы .']

# %%
sentenced_reviews = []

for review in reviews:
    sentenced_reviews += sent_tokenize(review.replace(".", " . "))

# %%
def has_alpha(x):
    return len(x) > 0 and max([l.isalpha() for l in x])

# %%
len(reviews), len(sentenced_reviews), len([x for x in sentenced_reviews if has_alpha(x)])
# Out:
# (1729, 3319, 3144)

# %%
reviews = [x for x in sentenced_reviews if has_alpha(x)]

# %%
comma_split_reviews = []

for review in reviews:
    comma_split_reviews += review.split(",")

# %%
len(reviews), len(comma_split_reviews)
# Out:
# (3144, 4873)

# %%
reviews = [x for x in comma_split_reviews if has_alpha(x) and len(x) >= 5]

# %%
len(reviews)
# Out:
# 4807

# %% [markdown]
# ### Токенизируем: с нормализацией и без

# %%
from collections import defaultdict
import matplotlib.pyplot as plt
import math
import numpy as np

# %%
import string
from nltk.tokenize import WhitespaceTokenizer, WordPunctTokenizer, TreebankWordTokenizer
from nltk.corpus import stopwords

stop_words = stopwords.words('russian')
stop_words.extend([x for x in string.punctuation] + ["«", "»", "это", "!", "!!", "!!!", "??"])
stop_words.remove("только")

# %%
import pymorphy2
morph = pymorphy2.MorphAnalyzer()

def normalize(x):
    return morph.parse(x)[0].normal_form

def extract_POS(x):
    return morph.parse(x)[0].tag.POS or "None"

# %%
tokenized_reviews = []
normalized_reviews = []

for r in reviews:
    tokens = [x for x in WordPunctTokenizer().tokenize(r) if x not in stop_words]
    tokens = [x for x in tokens if has_alpha(x)]
    tokenized_reviews.append(tokens)
    normalized_reviews.append([normalize(x) for x in tokens])

# %%
plt.figure(figsize=(16, 8))
plt.hist([len(x) for x in tokenized_reviews], bins=np.arange(0, 130, 2), rwidth=1)
plt.grid()
plt.title("Количество слов в отзыве (после очистки от стоп-слов)")
plt.xticks(np.arange(0, 130, 10))
plt.show()

# %%
POS_arr = []
for r in tokenized_reviews:
    POS_arr += [extract_POS(x) for x in r]

# %%
pos_counter = Counter(POS_arr)

# %%
ntop = len(pos_counter)
xs = np.arange(len(pos_counter))
ys = [y for x, y in pos_counter.most_common(ntop)][::-1]
labels = [x for x, y in pos_counter.most_common(ntop)][::-1]

plt.figure(figsize=(16, 8))
plt.title("Распределение слов по частям речи")

plt.barh(xs, ys)
plt.yticks(xs, labels=[x + "" for x in labels])
plt.ylabel("Labels")
plt.show()

# %% [markdown]
# Расшифровка тэгов:
# https://pymorphy2.readthedocs.io/en/stable/user/grammemes.html#grammeme-docs

# %% [markdown]
# ### Считаем частоты  n-грамм

# %%
def make_n_grams(arr, n, sep=" "):
    return [sep.join(arr[i:i+n]) for i in range(len(arr) - min(len(arr), n) + 1)]

# %%
N = 4

# %%
n_grams = defaultdict(list)
for tokens in tokenized_reviews:
    for i in range(1, N + 1):
        if len(tokens) >= i:
            n_grams[i] += make_n_grams(tokens, i)

# %%
counters = {}
for key, value in n_grams.items():
    counters[key] = Counter(value)

# %%
import pandas as pd

# %%
data = []
for key in counters.keys():
    for x, y in counters[key].items():
        data.append([key, x, y])
        
db = pd.DataFrame(data=data, columns=["ngram_len", "ngram", "cnt"])

# %%
db = db.sort_values(by=["ngram_len", "cnt"], ascending=[True, False], ignore_index=True)

# %%
db
# Out:
#        ngram_len                                ngram  cnt
# 0              1                              сдавать  485
# 1              1                                 кому  456
# 2              1                           приложение  389
# 3              1                               только  376
# 4              1                             квартиру  293
# ...          ...                                  ...  ...
# 29781          4       ваших акций спасибо обновление    1
# 29782          4  акций спасибо обновление приложение    1
# 29783          4          непонятно кого работают дек    1
# 29784          4    расисты славян дискриминируют дек    1
# 29785          4          сломали зато толерантно дек    1
#
# [29786 rows x 3 columns]

# %%
db.to_csv("ngrams.csv")

# %%
ncols = 1
nrows = math.ceil(N / ncols)
ntop = 30

fig, axs = plt.subplots(figsize=(10 * ncols, 10 * nrows), ncols=ncols, nrows=nrows)

keys = []

for i, key in enumerate(counters.keys()):
    ax = axs.reshape(-1)[i]
    xs = np.arange(ntop)
    ys = [y for x, y in counters[key].most_common(ntop)][::-1]
    labels = [x for x, y in counters[key].most_common(ntop)][::-1]
    ax.grid()
    ax.barh(xs, ys)
    ax.set_yticks(xs)
    ax.set_yticklabels(labels, rotation=0)
    ax.set_xlabel("N-Grams count: {}".format(sum([value for value in counters[key].values()])))
    for x, y in zip(xs, ys):
        ax.annotate(str(y), xy=(y, x), xytext=(y + 0.1, x - 0.3))

plt.show()

# %% [markdown]
# ### То же самое, но с нормализацией

# %%
n_grams = defaultdict(list)
for tokens in normalized_reviews:
    for i in range(1, N + 1):
        if len(tokens) >= i:
            n_grams[i] += make_n_grams(tokens, i)

# %%
counters = {}
for key, value in n_grams.items():
    counters[key] = Counter(value)

# %%
data = []
for key in counters.keys():
    for x, y in counters[key].items():
        data.append([key, x, y])
        
db = pd.DataFrame(data=data, columns=["ngram_len", "ngram", "cnt"])
db = db.sort_values(by=["ngram_len", "cnt"], ascending=[True, False], ignore_index=True)
db.to_csv("normalized_ngrams.csv")

# %%
ncols = 1
nrows = math.ceil(N / ncols)
ntop = 30

fig, axs = plt.subplots(figsize=(10 * ncols, 10 * nrows), ncols=ncols, nrows=nrows)

keys = []

for i, key in enumerate(counters.keys()):
    ax = axs.reshape(-1)[i]
    xs = np.arange(ntop)
    ys = [y for x, y in counters[key].most_common(ntop)][::-1]
    labels = [x for x, y in counters[key].most_common(ntop)][::-1]
    ax.grid()
    ax.barh(xs, ys)
    ax.set_yticks(xs)
    ax.set_yticklabels(labels, rotation=0)
    ax.set_xlabel("N-Grams count: {}".format(sum([value for value in counters[key].values()])))
    for x, y in zip(xs, ys):
        ax.annotate(str(y), xy=(y, x), xytext=(y + 0.1, x - 0.3))

plt.show()

# %% [markdown]
# ## Некоторые примеры

# %%
examples = [
    "славянин славянин",
    "дискриминация славянин дискриминация славянин",
]

dct = {x:[] for x in examples}

for i, x in enumerate(normalized_reviews):
    key = " ".join(x)
    if key in examples:
        dct[key].append(reviews[i])
        
for key, value in dct.items():
    print(key)
    for x in value:
        print("\t- " + x)
    print("---")
# Out:
# славянин славянин
# 	- славянам от славян
# 	- за славян за славян
# 	- за славян за славян
# 	- славян славян
# 	- за славян за славян
# 	- за славян за славян
# 	- за славян за славян
# 	- славяне славяне
# ---
# дискриминация славянин дискриминация славянин
# 	- дискриминация славян дискриминация славян
# 	- дискриминация славян дискриминация славян
# 	- дискриминация славян дискриминация славян
# 	- дискриминация славян дискриминация славян
# 	- дискриминация славян дискриминация славян
# ---

# %% [markdown]
# ## Word Embeddings

# %%
import gensim.downloader

# %%
list(gensim.downloader.info()['models'].keys())
# Out:
# ['fasttext-wiki-news-subwords-300',
#  'conceptnet-numberbatch-17-06-300',
#  'word2vec-ruscorpora-300',
#  'word2vec-google-news-300',
#  'glove-wiki-gigaword-50',
#  'glove-wiki-gigaword-100',
#  'glove-wiki-gigaword-200',
#  'glove-wiki-gigaword-300',
#  'glove-twitter-25',
#  'glove-twitter-50',
#  'glove-twitter-100',
#  'glove-twitter-200',
#  '__testing_word2vec-matrix-synopsis']

# %%
word_embeddings = gensim.downloader.load("word2vec-ruscorpora-300")

# %%
def review2vec(review, model):
    res = np.zeros(300)
    cnt = 0
    for word in review:
        pos = extract_POS(word)
        key = word + "_" + pos
        if key in model:
            res += model[key]
            cnt += 1
    return res / max(cnt, 1)

# %%
w2v_reviews = []
for r in normalized_reviews:
    w2v_reviews.append(review2vec(r, word_embeddings))

# %%
w2v_reviews = np.array(w2v_reviews)
w2v_reviews.shape
# Out:
# (4807, 300)

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=2)
pca_words = pca.fit_transform(w2v_reviews)

# %%
plt.scatter(pca_words[:, 0], pca_words[:, 1])
plt.title("Embeddings PCA")
plt.show()

# %%
from sklearn.cluster import DBSCAN, KMeans

# %%
eps = 1e-3
min_samples = 10

db = DBSCAN(eps=eps, metric="euclidean", min_samples=min_samples).fit(w2v_reviews)

labels = db.labels_
len(set(labels))
# Out:
# 28

# %%
normed_words
# Out:
# array([list(['дискриминация', 'собственник', 'жильё']), list(['русофоб']),
#        list(['ужас', 'убрать', 'возможность', 'указывать', 'национальность']),
#        ..., list(['ru']), list(['осторожно']),
#        list(['они', 'ваш', 'город', 'превратиться', 'аул'])], dtype=object)

# %%
words = np.array(reviews)
normed_words = np.array([" ".join(x) for x in normalized_reviews])

clusters = {}
normed_clusters = {}
sizes = {}
for label in set(labels):
    cluster = words[labels == label]
    normed_cluster = normed_words[labels == label]
    sizes[label] = len(cluster)
    clusters[label] = cluster
    normed_clusters[label] = normed_cluster
    
sizes_list = np.array(sorted([(x, y) for x,y in sizes.items()], key=lambda x: x[1], reverse=True))

plt.title("Cluster sizes")
plt.bar(sizes_list[:, 0], sizes_list[:, 1])
plt.show()

# %%
plt.figure(figsize=(10, 10))
for i in set(labels):
    s, a = (2, 1) if i != -1 else (0.1, 0.5)
    label = "{} : {}".format(i, sum(labels == i)) # if i != -1 else ""
    plt.scatter(
        pca_words[labels == i, 0], 
        pca_words[labels == i, 1],
        s=s,
        alpha=a,
        label=label)
plt.legend(loc=5)
plt.title("DBSCAN eps:{} min_samples:{} - Embeddings PCA".format(eps, min_samples))
plt.show()

# %%
n_top_clusters_to_plot = 1

sizes_to_plot = sizes_list[n_top_clusters_to_plot:, ]
sizes_to_plot = sizes_to_plot[sizes_to_plot[:, 1] > min_samples]

print("{} clusters cover {} reviews from {}".format(
    sizes_to_plot.shape[0],
    sum(sizes_to_plot[:, 1]),
    words.shape[0]
))
# Out:
# 24 clusters cover 2023 reviews from 4807

# %%
n_top_clusters_to_plot = 0

sizes_to_plot = sizes_list[n_top_clusters_to_plot:, ]
sizes_to_plot = sizes_to_plot[sizes_to_plot[:, 1] > min_samples]

print("{} clusters cover {} reviews from {}".format(
    sizes_to_plot.shape[0],
    sum(sizes_to_plot[:, 1]),
    words.shape[0]
))
# Out:
# 25 clusters cover 4777 reviews from 4807

# %%
n_examples = 15

for x in sizes_to_plot:
    print("Label {}, Cluster size: {}".format(x[0], x[1]))
    for review, normed_review in zip(clusters[x[0]][:n_examples], normed_clusters[x[0]][:n_examples]):
        print("\t- " + review) #+ " /\n\t\t (" + normed_review + ")")
    print("\n")
# Out:
# Label -1, Cluster size: 2754
# 	- дискриминация собственников жилья .
# 	- ужас из за убранной возможности указывать национальность
# 	- кому хочу и это буду славяне!🙋🏼‍♂️☀️ приложение ужасное
# 	- и проведайте там свои акции компании
# 	- как вы играете в толерастов и акции идут в упадок…
# 	-  плохо знающими русский язык
# 	-  вы сами же и усложнили поиск квартиры иностранцам ближнего зарубежья
# 	-  теперь им придется побегать и потрать кучу времени на поиск человека
# 	-  захочу только собакам сдавать буду
# 	-  а захочу бригаду строителей
# 	-  это не правила а бред .
# 	-  из-за новой политики не позволяющим делать объявления собственникам для сдачи только славянам!
# 	- не место толерантности
# 	- сдаём славянам без животных
# 	- эй цианисты
#
#
# Label 1, Cluster size: 1055
# 	-  костре приехали и чуть не избили нерусские за то что я им отказал!
# 	- удаляю навсегда!!!
# 	- спасибо
# 	-  которому безразлично на то
# 	- почему решаете вы
# 	- сам решу кому сдавать!
# 	- как хочу
# 	-  так и сдаю!
# 	-  так и буду .
# 	- а все очень просто .
# 	- не советую .
# 	- толерасты блм не пройдёт !
# 	- плохо!!!
# 	- не вам решать и блокировать .
# 	- постоянно зависаетiphone 11
#
#
# Label 7, Cluster size: 188
# 	- прекращаю пользоваться данным приложением
# 	- отвратительное приложение так ещё и нельзя написать кому хочешь сдавать
# 	- не удобное и глючное приложение очень не удобное и глючное
# 	- думаю все уже все поняли)))) приложение тормозит
# 	- отличное приложение!
# 	- приложение для латентных толерастов приложение для латентных толерастов
# 	-  выкидывает из приложения .
# 	-  удаляю приложение .
# 	- есть приложения лучше плохо
# 	-  кому мне сдавать жилье приложением больше пользоваться не буду
# 	- нестабильное приложение работает через раз
# 	-  неудобное приложение .
# 	- удаляю приложение
# 	- худшие приложение отвратительное
# 	- воняет приложение воняет
#
#
# Label 11, Cluster size: 155
# 	-  ненавистных вам славян
# 	- сдам только славянам!!!
# 	-  которые дискриминируют славян
# 	- только славянам .
# 	- )) только славянам
# 	- только славянам верните как было
# 	-  а хочу славянам
# 	-  и если только для славян - это можно писать .
# 	- славяне!
# 	- только для славян .
# 	- только славяне❤️
# 	- славянам от славян
# 	- мой жильё хочу сдавать только славянам!
# 	-  славян .
# 	- только славянам .
#
#
# Label 2, Cluster size: 135
# 	- я буду сдавать квартиру
# 	-  которые хотят заселиться всем табуном в мою квартиру .
# 	-  кому сдавать квартиру
# 	- почему решать кому-то кому я хочу сдавать квартиру?
# 	-  а кто будет платить мне за разгромленную или обворованную квартиру
# 	- не вам решать кому сдавать квартиру
# 	- из них:5 армяне8 русские2 украиныпроблемных было:4 из 5 армян1 из 8 русских0 из 2 украинцевкому я должен сдавать квартиры
# 	-  что ему квартиру не сдадут .
# 	- квартиру .
# 	-  кто будет жить в моей квартире
# 	-  кому сдавать собственную квартиру👎🏼
# 	- я как бы сам решу кому мне сдавать мою квартиру
# 	- вы не правы я не сдаю квартиру
# 	- повесточка добралась я хочу сам решать что делать и кому сдавать свои квартиры
# 	-  кому я буду сдавать свою квартиру .
#
#
# Label 3, Cluster size: 62
# 	- спасибо циан!
# 	- циан прогнулся!
# 	-  тому и сдаю циан обцианился
# 	- почему циан за меня решает?
# 	-  циан .
# 	- против циан!
# 	- прощайте циан
# 	- циан для русских \о зверьё
# 	- спасибо циан сегодня узнал
# 	- и никакой циан не будет мне указывать
# 	-  которые им циан навяжет?
# 	- black и циан .
# 	- прогнули циан кому хочу- тому сдаю!
# 	- удаляйте циан и никогда не устанавливайте!
# 	- спасибо циан!
#
#
# Label 10, Cluster size: 47
# 	- дискриминация славян!
# 	- дискриминация славян отвратительна .
# 	- дискриминация славян!
# 	- что за дискриминация славян?!
# 	- дискриминация славян .
# 	- дискриминация славян
# 	- дискриминация славян дискриминация славян
# 	- дискриминация славян?
# 	- отменяйте дискриминация славян
# 	- дискриминация славян как оно есть
# 	- дискриминация хочу сдаю только славянам
# 	- дискриминация славян дискриминация славян
# 	- дискриминация славян уже никуда не годится
# 	- писать «только славянам» это ужасная дискриминация
# 	- дискриминация только славянам
#
#
# Label 6, Cluster size: 46
# 	- дискриминация!
# 	- отвратительно дискриминация русских
# 	- нет дискриминации .
# 	- дискриминация!
# 	- нет дискриминации!
# 	- дискриминация дискриминация русских!
# 	- дискриминация!
# 	- дискриминация найс ущемляете
# 	- дискриминация указывают
# 	- я против дискриминации!
# 	- мы против дискриминации!
# 	- дискриминация!
# 	- плохо дискриминация русских
# 	- дискриминация нельзя указывать
# 	- долой дискриминацию дискриминации !
#
#
# Label 4, Cluster size: 39
# 	- придется разговаривать с людьми
# 	-  но поддерживаю людей
# 	- видеть людей и разворачиваться
# 	-  неуваженее к людям .
# 	- чем интеллигентнее человек
# 	- и русские люди будут сами решать
# 	-  культурным белым людям
# 	- а людям
# 	- почему-то люди забывают
# 	- не даёт помогать нуждающимся людям
# 	- нормальных людей станет больше!
# 	- от русского человека .
# 	- vox populi — vox dei человек вправе сам решать
# 	- люди ж звонить будут
# 	- так вы еще и ограничиваете людей .
#
#
# Label 9, Cluster size: 29
# 	-  много старых объявлений .
# 	- много левых объявлений раньше было ничего
# 	- и я хочу писать в объявлении
# 	-  просто этого не будет в объявлении .
# 	- плохо работает начинаю писать объявление как появляется повесточка .
# 	-  что запретили расистские объявления .
# 	-  объявление удаляют
# 	-  а объявление не выложили
# 	- я сам решаю что мне писать в своём объявлении!!
# 	- много левых объявлений очень много левых объявлений
# 	- арендовзятелям - кататься по объявлениям и искать кто же им сдаст жильё .
# 	-  то снимут объявление
# 	-  все равно решил выявить объявление .
# 	- отвратительно зачем мне московские объявления?
# 	- моё объявление отклоняют из за якобы дескриминации
#
#
# Label 17, Cluster size: 29
# 	- худший сервис .
# 	- советую не пользоваться этим сервисом!
# 	- плохой сервис .
# 	- другие сервисы намного удобнее и быстрее
# 	- плохо сказано про сервис уже достаточно .
# 	- ужасный сервис ужасный сервис
# 	- худший сервис
# 	- много крутых новых сервисов
# 	- есть другие сервисы
# 	- буду рекомендовать всем пользоваться только вашим сервисом .
# 	- отвратный сервис
# 	-  я этим сервисом больше не пользуюсь
# 	- самый худший сервис
# 	-  сам сервис неплохой
# 	- не клиентоориентированный сервис очень плохо
#
#
# Label 21, Cluster size: 26
# 	-  которые имеют право сами выбирать кому сдавать своё жильё .
# 	- вы это право уничтожили
# 	- я в праве сдавать своё жильё кому пожелаю!
# 	-  это моё право!
# 	- я в праве выбирать самостоятельно съёмщиков
# 	- это мое право
# 	- мое право!
# 	- я сам в праве решать кому сдавать
# 	-  я имею право где угодно и кому угодно подобное писать и говорить .
# 	-  но я сам в праве выбирать
# 	- имею право сдавать кому хочу
# 	- это вообще право
# 	-  это моё право .
# 	-  что у них есть какое то право это контролировать?
# 	-  не имеют права выбирать кому сдавать и продавать))))
#
#
# Label 0, Cluster size: 24
# 	- русофобы!!
# 	- русофобы
# 	- русофобы!
# 	- ну раз вы русофобы
# 	- русофобы русофобы
# 	- русофобы!
# 	- русофобы!
# 	- нет русофобам!
# 	- нет русофобам решили прогнуться ?
# 	- русофобы!
# 	- русофобы говноприложение!
# 	- русофобы
# 	- р русофобы
# 	- русофобы👎 русофобы
# 	- русофобы русофобы .
#
#
# Label 19, Cluster size: 24
# 	-  я хочу сдавать свою квартиру только славянам
# 	- ужс вы сами то сдавали бы не славянам квартиры?
# 	- сдам квартиру только славянам
# 	- раньше писать квартира славянам я не ездить .
# 	- квартиры для славян!
# 	-  так как моя квартира только для славян
# 	- если я хочу сдавать квартиры только славянам
# 	- я сам решу кому сдавать квартиру я славянин и буду сдавать квартиру только славянам
# 	- верните назад писать сдам квартиру славянам!
# 	- хочу сдавать квартиру только славянам!
# 	-  не дают сдавать квартиры славянам
# 	- хочу сдавать свою квартиру только славянам!!!
# 	-  что сдам квартиру только славянам .
# 	- я сдавал и буду сдавать свои квартиры только славянам
# 	- толерантненько хочу свою квартиру сдавать только славянам .
#
#
# Label 18, Cluster size: 18
# 	- с их толерантностью?
# 	-  хотели хайпануть на толерантности
# 	- у нас нет толерантности
# 	- захотели поиграть в толерантность?
# 	- играйте сами в свою толерантность
# 	- против чрезмерной толерантности .
# 	-  а не толерантность!!
# 	- никакой толерантности
# 	- толерантность всегда считал
# 	- хотели поиграть в толерантность
# 	- вы то куда со своей толерантностью?
# 	-  нужно и здесь свою толерантность протолкнуть .
# 	- типо толерантность
# 	- вы то куда полезли с толерантностью
# 	- толерантность должна быть адекватной
#
#
# Label 12, Cluster size: 17
# 	- понятное дело
# 	-  так дела не делаются .
# 	-  мое личное дело
# 	- не ваше собачье дело сдаю и буду сдавать кому захочу .
# 	-  это мое дело
# 	- не ваше дело буду сдавать кому хочу
# 	-  это мое дело .
# 	- по делу
# 	- не ваше дело кому хочу
# 	- мое дело
# 	- кому хотим тем и сдаём не ваше дело
# 	- такие дела .
# 	- не ваше дело!
# 	- такие дела!
# 	- займитесь своим делом!
#
#
# Label 15, Cluster size: 16
# 	-  молодцы .
# 	- вы молодцы!
# 	- молодцы правильно сделали
# 	- молодцы
# 	-  молодцы .
# 	- молодцы
# 	- молодцы огромное спасибо
# 	- молодцы!
# 	- молодцы!
# 	-  молодцы
# 	- молодцы
# 	- вы молодцы!
# 	- молодцы
# 	- молодцы .
# 	- молодцы
#
#
# Label 25, Cluster size: 16
# 	-  удаляю и одна звезда .
# 	- жирный минус поставлю 5 звёзд только сами знаете кому
# 	- первую звезду вы получаете бесплатно!
# 	- одна звезда!
# 	- заигрались ловите одну звезду
# 	- одна звезда за это
# 	- одна звезда за это
# 	- 1 звезда!
# 	-  за что одна звезда)
# 	-  по этому одна славянская звезда из пяти .
# 	- держите одну звезду
# 	-  принимайте 1 звезду .
# 	- 1 звезда .
# 	-  что нельзя поставить ниже 1 звёзды .
# 	- одна звезда заслужили😉
#
#
# Label 5, Cluster size: 15
# 	-  что делать с моей собственностью
# 	- указывают как мне распоряжаться моей собственностью .
# 	-  кому сдавать свою собственность .
# 	- прощайте кто вы такие чтобы за меня решать кому сдавать мою собственность
# 	-  или иной собственности
# 	-  кому я хочу сдавать свою собственность?!
# 	-  кому сдавать свою собственность
# 	-  не ваша собственность
# 	-  кому и как сдавать их собственность?
# 	- моя собственность .
# 	-  кому мне сдавать собственность .
# 	-  это частная собственность .
# 	- частная собственность
# 	- каждый может распоряжаться своей собственностью
# 	-  кому сдавать свою собственность .
#
#
# Label 24, Cluster size: 15
# 	- отзыв не понятно
# 	- что-то не сходится отзывы накручены
# 	- s скорее всего отзыв удалят
# 	- получайте отзыв
# 	- хорошие отзывы накручены!
# 	- удаляют отзыв?
# 	- не вижу свой негативный отзыв
# 	- отзыв считаю
# 	-  отзыв и удаляю нафиг .
# 	-  чтобы написать отзыв!
# 	-  будьте готовы к плохим отзывам
# 	- почему мой отзыв удалили?
# 	- отзыв не советую
# 	- отзыв сами знаете за что
# 	- отзыв не рекомендую
#
#
# Label 13, Cluster size: 14
# 	-  просто ужас
# 	- все тормозит какой ужас
# 	- полный ужас за всё вам
# 	- в 21 такой ужас .
# 	- ужас .
# 	-  просто ужас !
# 	-  это просто какой то ужас
# 	- не советую ужас
# 	- ужас возомнили себя крутыми?
# 	- ужас!
# 	- я в ужасе .
# 	- ужас!
# 	- ужас просто!!
# 	- ужас!!!
#
#
# Label 22, Cluster size: 14
# 	- никто вам не мешает не сдавать вашу недвижимость кому либо .
# 	- недвижимостью
# 	-  хотят указывать кому сдавать а кому не сдавать мою недвижимость
# 	-  продавать мою недвижимость!
# 	- сдаю свою недвижимость
# 	-  кому сдавать мою недвижимость?
# 	-  кому сдавать недвижимость .
# 	-  кому сдавать свою недвижимость !
# 	-  что я сам выбираю кому сдавать свою недвижимость
# 	-  кому мне сдавать свою недвижимость ?!
# 	-  что есть я-недвижимость
# 	- мы сами решаем кому сдавать свою недвижимость
# 	-  кому я буду сдавать недвижимость .
# 	- недвижимость моя
#
#
# Label 14, Cluster size: 13
# 	- новые правила отработали повесточку
# 	- отменить новые правила!
# 	- тупые новые правила !!!
# 	- и правила здесь должны устанавливать русские .
# 	-  чтобы отблагодарить вас за новое правило)
# 	- новые русофобские правила зачем вы нужны
# 	-  то новые правила .
# 	- рад новому правилу надеюсь
# 	- так как это правила моего жилья
# 	- правила мне не нравится
# 	- новые правила за то
# 	- вы вели новое правило
# 	- есть какие-то правила
#
#
# Label 16, Cluster size: 13
# 	- ещё и нововведения непонятные ввели .
# 	- спасибо спасибо за нововведения .
# 	- что за бредовые нововведения?
# 	-  плюс «нововведения»…
# 	- я сам решу кому сдавать скоро вы скатитесь за вообще нововведение  .
# 	- очень плохо не поддерживаю последние нововведения .
# 	-  постоянные нововведения
# 	- нововведения радуют .
# 	- что за глупые нововведения?
# 	- нововведение мне казалось
# 	- ваши нововведения все равно не заставят нас сдавать всякому зверью жильё
# 	- нововаедения хорошие нововведения
# 	- 🔝🔝🔝 спасибо за последние нововведения!
#
#
# Label 20, Cluster size: 13
# 	- рассисты не могу сдавать тому
# 	- плохо не могу сдать жильё
# 	-  что можете указывать
# 	- да я даже дозвониться не могу до 99%!
# 	- я могу написать «только с 2ндфл» .
# 	- почему я не могу решать
# 	-  кому я мог ее сдать
# 	-  почему я не могу указать это .
# 	- толерасты почему я не могу указать
# 	- ужасный интерфейсне могу выложить обьявление даже
# 	-  хотя могли бы сразу прочитать
# 	-  а я их ставить не могу?
# 	-  почему я не могу указать

# %%
data = []

for x in sizes_to_plot:
    label = x[0]
    cluster_size = x[1]
    for review, normed_review in zip(clusters[label], normed_clusters[label]):
        data.append([label, cluster_size, review, normed_review])
        
        
db = pd.DataFrame(data=data, columns=["cluster_label", "cluster_size", "review", "normed_review"])
db.to_csv("clustered_reviews.csv")
