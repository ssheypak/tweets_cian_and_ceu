# %% [markdown]
# ### Загружаем текст и ищем, по какому символу разбить

# %%
with open("data/reviews.txt", "r") as file:
    text = file.read()
    
text = text.lstrip("INTELLIGENCE\n\n")

# %%
tokens = text.split()

# %%
from collections import Counter
c = Counter(tokens)
c.most_common(25)
# Out:
# [('1.215', 1244),
#  ('и', 640),
#  ('не', 636),
#  ('1.214.1', 484),
#  ('в', 432),
#  ('сдавать', 430),
#  ('кому', 405),
#  ('на', 259),
#  ('что', 257),
#  ('только', 234),
#  ('я', 217),
#  ('Не', 205),
#  ('за', 192),
#  ('Дискриминация', 182),
#  ('приложение', 179),
#  ('квартиру', 176),
#  ('а', 164),
#  ('хочу', 163),
#  ('с', 158),
#  ('Я', 146),
#  ('для', 145),
#  ('это', 144),
#  ('славян', 139),
#  ('как', 134),
#  ('вы', 133)]

# %% [markdown]
# Разбиваем

# %%
import re
reviews = [x.strip().lower() for x in re.split("1.215|1.214.1", text)]

# %%
reviews[:5]
# Out:
# ['дискриминация собственников жилья. русофобы!!!',
#  'ужас из за убранной возможности указывать национальность, костре приехали и чуть не избили нерусские за то что я им отказал! удаляю навсегда!!!!',
#  'я буду сдавать квартиру,кому хочу и это буду славяне!🙋🏼\u200d♂️☀️ приложение ужасное,и проведайте там свои акции компании,как вы играете в толерастов и акции идут в упадок…',
#  'спасибо циан! придется разговаривать с людьми, плохо знающими русский язык, которые хотят заселиться всем табуном в мою квартиру. спасибо, вы сами же и усложнили поиск квартиры иностранцам ближнего зарубежья, теперь им придется побегать и потрать кучу времени на поиск человека, которому безразлично на то, кому сдавать квартиру',
#  'почему решать кому-то кому я хочу сдавать квартиру? почему решаете вы, что делать с моей собственностью, захочу только собакам сдавать буду, а захочу бригаду строителей, это не правила а бред.']

# %% [markdown]
# ### Токенизируем: с нормализацией и без

# %%
from collections import defaultdict
import matplotlib.pyplot as plt
import math
import numpy as np

# %%
import string
from nltk.tokenize import WhitespaceTokenizer, WordPunctTokenizer, TreebankWordTokenizer
from nltk.corpus import stopwords

stop_words = stopwords.words('russian')
stop_words.extend([x for x in string.punctuation] + ["«", "»", "это", "циан", "!!!"])
stop_words.remove("только")

# %%
"только" in stop_words
# Out:
# False

# %%
import pymorphy2
morph = pymorphy2.MorphAnalyzer()

def normalize(x):
    return morph.parse(x)[0].normal_form

def extract_POS(x):
    return morph.parse(x)[0].tag.POS or "None"

# %%
normalize("славян")
# Out:
# 'славянин'

# %%
tokenized_reviews = []
normalized_reviews = []

for r in reviews:
    tokens = [x for x in WordPunctTokenizer().tokenize(r) if x not in stop_words]
    tokenized_reviews.append(tokens)
    normalized_reviews.append([normalize(x) for x in tokens])

# %%
normalized_reviews
# Out:
# [['дискриминация', 'собственник', 'жильё', 'русофоб'],
#  ['ужас',
#   'убрать',
#   'возможность',
#   'указывать',
#   'национальность',
#   'костёр',
#   'приехать',
#   'избить',
#   'нерусский',
#   'отказать',
#   'удалять',
#   'навсегда',
#   '!!!!'],
#  ['быть',
#   'сдавать',
#   'квартира',
#   'кто',
#   'хотеть',
#   'быть',
#   'славянин',
#   '!🙋🏼\u200d♂️☀️',
#   'приложение',
#   'ужасный',
#   'проведать',
#   'свой',
#   'акция',
#   'компания',
#   'играть',
#   'толераст',
#   'акция',
#   'идти',
#   'упадок',
#   '…'],
#  ['спасибо',
#   'прийтись',
#   'разговаривать',
#   'человек',
#   'плохо',
#   'знающий',
#   'русский',
#   'язык',
#   'который',
#   'хотеть',
#   'заселиться',
#   'весь',
#   'табуном',
#   'мой',
#   'квартира',
#   'спасибо',
#   'сам',
#   'усложнить',
#   'поиск',
#   'квартира',
#   'иностранец',
#   'ближний',
#   'зарубежье',
#   'прийтись',
#   'побегать',
#   'потратить',
#   'куча',
#   'время',
#   'поиск',
#   'человек',
#   'который',
#   'безразличный',
#   'кто',
#   'сдавать',
#   'квартира'],
#  ['почему',
#   'решать',
#   'кто',
#   'кто',
#   'хотеть',
#   'сдавать',
#   'квартира',
#   'почему',
#   'решать',
#   'делать',
#   'мой',
#   'собственность',
#   'захотеть',
#   'только',
#   'собака',
#   'сдавать',
#   'быть',
#   'захотеть',
#   'бригада',
#   'строитель',
#   'правило',
#   'бред'],
#  ['дискриминация', 'решить', 'кто', 'сдавать'],
#  ['хотеть',
#   'сдавать',
#   'прекращать',
#   'пользоваться',
#   'данные',
#   'приложение',
#   'новый',
#   'политика',
#   'позволять',
#   'делать',
#   'объявление',
#   'собственник',
#   'сдача',
#   'только',
#   'славянин',
#   'место',
#   'толерантность'],
#  ['сдавать', 'славянин', 'животное'],
#  ['эй',
#   'цианистый',
#   'квартира',
#   'только',
#   'усложнить',
#   'жизнь',
#   'кавказоид',
#   'сдавать',
#   'славянин',
#   'быть',
#   'просто',
#   'встреча',
#   'лицо',
#   'быть',
#   'говорить'],
#  ['самый',
#   'непопулярный',
#   'приложение',
#   'какой',
#   'право',
#   'иметь',
#   'блокировать',
#   'объявление',
#   'сдача',
#   'квартира',
#   'только',
#   'славянин',
#   'мой',
#   'имущество',
#   'распоряжаться',
#   'хотеть',
#   'плач',
#   'деньга',
#   'размещение',
#   'платить',
#   'разгромить',
#   'обворовать',
#   'квартира'],
#  ['название',
#   'данный',
#   'сайт',
#   'заниматься',
#   'слив',
#   'объявление',
#   'агенство',
#   'этаж'],
#  ['русофоб'],
#  ['пробить',
#   'дно',
#   'очень',
#   'просто',
#   'достаточно',
#   'сделать',
#   'шаг',
#   'тот',
#   'сторона',
#   'единица',
#   'заниматься',
#   'дискриминация',
#   'славянин'],
#  ['нововведение', 'квартира', 'мой', 'правило'],
#  ['утиль',
#   'самый',
#   'отвратительный',
#   'приложение',
#   'поиск',
#   'недвижимость',
#   'интерфейс',
#   'тормозить',
#   'старый',
#   'объявление'],
#  ['дно', 'пробить', 'усложнить', 'жизнь', 'другой', 'советовать'],
#  ['толераст', 'блм', 'пройти'],
#  ['решать', 'кто', 'сдавать', 'квартира'],
#  ['сайт',
#   'разжигать',
#   'вражда',
#   'русофоб',
#   'дискриминировать',
#   'русский',
#   'население'],
#  ['плохо',
#   'приложение',
#   'владелец',
#   'устанавливать',
#   'свой',
#   'правило',
#   'арендатор'],
#  ['удалять', 'ужасный', 'приложение', 'недавний', 'время'],
#  ['мельников',
#   'суд',
#   'дискриминация',
#   'славянин',
#   'собственник',
#   'право',
#   'писать',
#   'кто',
#   'какой',
#   'условие',
#   'сдавать',
#   'аренда',
#   'квартира',
#   'решать',
#   'блокировать'],
#  ['приложение',
#   'очень',
#   'разумный',
#   'фильтр',
#   'конкурент',
#   'гораздо',
#   'удобный',
#   'гораздо',
#   'пользователь'],
#  ['отвратительный',
#   'приложение',
#   'ещё',
#   'написать',
#   'кто',
#   'хотеть',
#   'сдавать'],
#  ['удобный',
#   'глючный',
#   'приложение',
#   'очень',
#   'удобный',
#   'глючный',
#   'постоянно',
#   'зависаетiphone',
#   '11'],
#  ['только',
#   'плохой',
#   'сделать',
#   'кто',
#   'сдавать',
#   'вынудить',
#   'позвонить',
#   'написать',
#   'приехать',
#   'равно',
#   'отказать'],
#  ['1', 'решать', 'кто', 'сдавать', 'кто', 'сдавать', 'имущество', '!!'],
#  ['авить', 'интересный', 'нету', 'авить'],
#  ['дискриминация',
#   'угнетение',
#   'коренной',
#   'население',
#   'знать',
#   'помойка',
#   'думать',
#   'настолько',
#   'оподливиться',
#   'свой',
#   'страна',
#   'открыто',
#   'угнетать',
#   'исконно',
#   'русский',
#   'население',
#   'пытаться',
#   'повлиять',
#   'условие',
#   'предоставление',
#   'услуга',
#   'приезжий',
#   'обычно',
#   'происходить',
#   'лишь',
#   'оподливиться',
#   'вызвать',
#   'огромный',
#   'волна',
#   'хейт',
#   'сторона',
#   'давний',
#   'пользователь',
#   'ваш',
#   'сервис',
#   'сторона',
#   'обычный',
#   'ненавистный',
#   'славянин'],
#  ['лул', 'отвратительный', 'обновление'],
#  ['собственник',
#   'иметь',
#   'право',
#   'выбор',
#   'тот',
#   'человек',
#   'который',
#   'принимать',
#   'решение',
#   'введение',
#   'такой',
#   'запрет',
#   'сдавать',
#   'квартира',
#   'свой',
#   '5',
#   'квартира',
#   'сдаваться',
#   'последний',
#   '6',
#   'год',
#   '15',
#   'арендатор',
#   '5',
#   'армяне8',
#   'русские2',
#   'украиныпроблёмный',
#   '4',
#   '5',
#   'армян1',
#   '8',
#   'русских0',
#   '2',
#   'украинцевкий',
#   'должный',
#   'сдавать',
#   'квартира',
#   'опираться',
#   'свой',
#   'эмпирический',
#   'опыт',
#   'вроде',
#   'закром',
#   'сидеть',
#   'экономист',
#   'узнать',
#   'такой',
#   'риск',
#   'актив',
#   'норма',
#   'доходность',
#   'актив',
#   'понятный',
#   'дело',
#   'арендный',
#   'платёж',
#   'постоянно',
#   'угроза',
#   'невыплата',
#   'быть',
#   'сдавать',
#   'квартира',
#   'неплатёжеспособный',
#   'нечистый',
#   'рука',
#   'арендатор',
#   'который',
#   'постоянно',
#   'пытаться',
#   'иной',
#   'образ',
#   'обмануть',
#   'выполнять',
#   'свой',
#   'обязательство',
#   'подумать',
#   'это',
#   'пока',
#   'шортана',
#   'ваш',
#   'акция',
#   'заработать',
#   'ваш',
#   'непрофессионализм'],
#  ['отстой',
#   'какой',
#   'иметь',
#   'право',
#   'указывать',
#   'кто',
#   'сдавать',
#   'квартира'],
#  ['очень', 'удобный', 'приложение', 'найти', 'квартира', 'спасибо'],
#  ['минус',
#   'какой',
#   'пора',
#   'шарага',
#   'тип',
#   'циан',
#   'мочь',
#   'указывать',
#   'собственник',
#   'кто',
#   'хотеть',
#   'видеть',
#   'арендатор'],
#  ['мда', 'прога', 'уг'],
#  ['знать',
#   'кто',
#   'потребоваться',
#   'приложение',
#   'пожалуй',
#   'принцип',
#   'уходить',
#   'яндекс',
#   'недвижимость'],
#  ['хотеть',
#   'сдавать',
#   'квартира',
#   'только',
#   'славянин',
#   'слава',
#   'род',
#   'славянский'],
#  ['сам', 'решить', 'кто', 'сдавать', 'спасибо'],
#  ['разочаровать', 'прогнуться'],
#  ['приехать',
#   'называться',
#   'ограничивать',
#   'уровень',
#   'сервис',
#   'арендодатель',
#   'приемлемый',
#   'человек',
#   'условие',
#   'сдача',
#   'жильё',
#   'невозможность',
#   'обозначить',
#   'сразу',
#   'приводить',
#   'лишний',
#   'проблема',
#   'лишний',
#   'звонок',
#   'объявление',
#   'который',
#   'потенциальный',
#   'арендатор',
#   'знать',
#   'квартира',
#   'сдать'],
#  ['русофоб',
#   'человек',
#   'право',
#   'распоряжаться',
#   'свой',
#   'собственность',
#   'сдавать',
#   'лицо',
#   'славянский',
#   'внешность',
#   'решать',
#   'только',
#   'собственник',
#   'тьфу',
#   'чертовый',
#   'русофоб',
#   'кол'],
#  ['сдать', 'только', 'славянин', 'высера', 'толераст'],
#  ['левак',
#   'убить',
#   'ещё',
#   'сервис',
#   'дискриминация',
#   'отношение',
#   'русский',
#   'гениально',
#   'придумать'],
#  ['первый', 'шаг', 'борьба', 'ксенофобия', 'молодец'],
#  ['думать',
#   'понять',
#   '))))',
#   'приложение',
#   'тормозить',
#   'работать',
#   'дофига',
#   'реклама',
#   'просто',
#   'ужас'],
#  ['отличный',
#   'приложение',
#   'спасибо',
#   'отказ',
#   'расовый',
#   'дискриминация',
#   'некоторый',
#   'ущемленец',
#   'стереотипный',
#   'мышление',
#   'нормальный',
#   'человек',
#   'мочь',
#   'найти',
#   'жильё'],
#  ['удобно', 'нравиться'],
#  ['ясно', 'решить', 'кто', 'сдавать'],
#  ['славянин',
#   'сдать',
#   'устроить',
#   'дом',
#   'небольшой',
#   'аул',
#   'быть',
#   'пасти',
#   'баранов',
#   'резать',
#   'голова',
#   'балкон',
#   'детский',
#   'площадка',
#   'русофоб'],
#  ['приложение',
#   'латентный',
#   'толераст',
#   'приложение',
#   'латентный',
#   'толераст'],
#  ['только',
#   'словян',
#   'какой',
#   'иметь',
#   'право',
#   'указывать',
#   'кто',
#   'селить',
#   'мой',
#   'квартира',
#   'рехнуться',
#   'приложение',
#   'снос'],
#  ['мерзость', 'давать', 'быть', 'решать', 'жить', 'мой', 'квартира'],
#  ['плохой',
#   'приложение',
#   'недвижимость',
#   'решать',
#   'кто',
#   'сдавать',
#   'квартира'],
#  ['минус',
#   'надеяться',
#   'чурек',
#   'изн',
#   'силовать',
#   'ваш',
#   'дочь',
#   'ваш',
#   'квартира'],
#  ['работоспособность',
#   'приложение',
#   'очень',
#   'плохо',
#   'работать',
#   'постоянно',
#   'вылетать'],
#  ['просто', 'самый', 'негативный', 'ресурс', 'сдача', 'жильё', 'надеяться'],
#  ['иметь', 'дело', 'прога', 'который', 'дискриминировать', 'славянин'],
#  ['удобно',
#   'удобный',
#   'приложение',
#   'выбрать',
#   'сдача',
#   'квартира',
#   'кто',
#   'хотеть',
#   'сдавать'],
#  ['новый',
#   'правило',
#   'отработать',
#   'повесточка',
#   'молодец',
#   'право',
#   'выбирать',
#   'человек',
#   'который',
#   'жить',
#   'дом',
#   'зависеть',
#   'политический',
#   'повестка',
#   'частный',
#   'собственность',
#   'право',
#   'распоряжаться',
#   'удобно',
#   'владелец',
#   'священный'],
#  ['только', 'славянин', 'почему', 'указывать', 'национальность'],
#  ['дискриминация', 'расистский', 'приложение', 'крайне', 'некомендуть'],
#  ['только', 'славянин', 'недвижимость', 'мой', 'правило'],
#  ['👎', 'крайность', 'крайность'],
#  ['толерантность', 'здорово', 'вернуть', 'фильтр'],
#  ['дух',
#   'запад',
#   'навязать',
#   'толерантность',
#   'запретить',
#   'арендодатель',
#   'выбирать',
#   'жилец',
#   'свой',
#   'усмотрение',
#   'сильный',
#   'шаг',
#   '…',
#   'бездна',
#   'крайне',
#   'разочаровать',
#   'недовольный',
#   'нынешний',
#   'положение',
#   'дело',
#   'циан',
#   'сколько',
#   'заплатить',
#   'опрометчивый',
#   'шаг'],
#  ['))', 'только', 'славянин', 'около'],
#  ['сдача', 'квартира', 'кто', 'хотеть', 'тот', 'сдавать'],
#  ['плохо',
#   'получиться',
#   'выбрать',
#   'кто',
#   'сдавать',
#   'собственный',
#   'квартира',
#   '👎🏼'],
#  ['странный',
#   'нововведение',
#   'несильно',
#   'удобный',
#   'приложение',
#   'ещё',
#   'нововведение',
#   'непонятный',
#   'ввести',
#   '...',
#   'стать',
#   'дискомфортно',
#   'пользоваться',
#   'многий'],
#  ['оценка',
#   '0',
#   'суть',
#   'запрещать',
#   'сдавать',
#   'квартира',
#   'кто',
#   'хотеть',
#   'вскоре',
#   'дойти',
#   'смешной',
#   'сервис',
#   'буквально',
#   'заставлять',
#   'сдавать',
#   'квартира',
#   'кто',
#   'попасть',
#   'плохой',
#   'сервис',
#   '0'],
#  ['оценка',
#   'отвратительный',
#   'приложение',
#   'корректный',
#   'работа',
#   'постоянно',
#   'зависать',
#   'выкидывать',
#   'приложение',
#   'советовать',
#   '👎🏻👎🏻👎🏻👎🏻'],
#  ['смех',
#   'смех',
#   'решать',
#   'кто',
#   'должный',
#   'сдавать',
#   'свой',
#   'имущество',
#   'ваш',
#   'услуга',
#   'нуждаться'],
#  ['ложь', 'обман', 'обращаться', 'другой', 'место'],
#  ['кто',
#   'хотеть',
#   'тот',
#   'сдавать',
#   'обцианиться',
#   'иметь',
#   'право',
#   'указывать',
#   'свой',
#   'требование',
#   'свой',
#   'квартира'],
#  ['отменить', 'новый', 'правило', '1', 'звезда', 'новый', 'правило'],
#  ['любитель',
#   'безнационал',
#   'прочий',
#   'подлизона',
#   'мир',
#   'животное',
#   'россия',
#   'русский',
#   'обезьяна',
#   'место',
#   'дикий',
#   'природа',
#   'решить',
#   'кто',
#   'сдавать',
#   'мой',
#   'квартира',
#   'кто',
#   'сдавать',
#   'около',
#   'кто',
#   'возомнить',
#   'диктовать',
#   'человек',
#   'обращаться',
#   'недвижимость',
#   'прогуляться',
#   'гудвина',
#   'сказочный'],
#  ['дизлайк', 'мощный', 'дизлайк', 'удар', 'один', 'звезда'],
#  ['1',
#   'звезда',
#   'отвратительный',
#   'приложение',
#   'квартира',
#   'соответствовать',
#   'действительность'],
#  ['россия',
#   'америка',
#   'жить',
#   '???',
#   'почему',
#   'мочь',
#   'написать',
#   'продавать',
#   'квартира',
#   'только',
#   'человек',
#   'славянский',
#   'внешность',
#   '???',
#   'грёбаный',
#   'америка',
#   'толерантность',
#   'че',
#   'мой',
#   'больший',
#   'часть',
#   'население',
#   'россия',
#   'человек',
#   'славянский',
#   'внешность',
#   '…',
#   'пока',
#   'исправить',
#   'быть',
#   'фейк',
#   'снижать',
#   'оценка'],
#  ['отвратительный', '👎🏻'],
#  ['только',
#   'славянин',
#   'вернуть',
#   'хотеть',
#   'сдавать',
#   'квартира',
#   'только',
#   'славянин',
#   'собственность',
#   'мой',
#   'право'],
#  ['новый', 'политика', 'вы', 'будушея', 'молодец'],
#  ['тот',
#   'страна',
#   'повесточка',
#   'пихать',
#   'сам',
#   'решить',
#   'кто',
#   'сдавать',
#   'квартира',
#   'кто',
#   'ваш',
#   'мнение',
#   'дорогой',
#   'помойка'],
#  ['плохо',
#   'никакой',
#   'клиентоориентированность',
#   'качество',
#   'обслуживание',
#   'нуль',
#   'стать',
#   'компания',
#   'очень',
#   'плохо',
#   'относиться',
#   'свой',
#   'клиент',
#   'качать',
#   'приложение',
#   'пользоваться',
#   'данные',
#   'сервис'],
#  ['дискриминация',
#   'славянин',
#   'приложение',
#   'диктовать',
#   'жить',
#   'авить',
#   'общий',
#   'этот',
#   'шарага',
#   'скоро',
#   'закрыться',
#   'коренной',
#   'народ',
#   'перестать',
#   'пользоваться'],
#  ['рассистый',
#   'мочь',
#   'сдавать',
#   'тот',
#   'кто',
#   'хотеть',
#   'хотеть',
#   'славянин'],
#  ['сервис',
#   'отстой',
#   'хотеть',
#   'писать',
#   'быть',
#   'угодный',
#   'только',
#   'славянин',
#   'писать',
#   'славянин',
#   'советовать',
#   'пользоваться',
#   'это',
#   'сервис'],
#  ['русофобский',
#   'приложение',
#   'отсутсвовать',
#   'возможность',
#   'корректно',
#   'обозначить',
#   'свой',
#   'условие',
#   'сдача',
#   'недвижимость',
#   'аренда',
#   'создать',
#   'поле',
#   'дальнейший',
#   'конфликт'],
#  ['работать', 'далёкий', 'непрошеный', 'гость'],
#  ['левый', 'объявление', 'ранний', 'испортиться'],
#  ['граница',
#   'решение',
#   'сдавать',
#   'сдавать',
#   'квартира',
#   'приезжий',
#   'дело',
#   'владелец',
#   'квартира',
#   'запрещать',
#   'указывать',
#   'национальность',
#   'быть',
#   'готовый',
#   'тот',
#   'самый',
#   'приезжий',
#   'быть',
#   'ходить',
#   'мороз',
#   'отказать',
#   'очно',
#   'свинский',
#   'отношение',
#   'гражданин',
#   'наш',
#   'страна',
#   'неуважение',
#   'приезжий',
#   'давать',
#   'соблюдать',
#   'граница',
#   'лезть',
#   'чужой',
#   'дом',
#   'свой',
#   'уклад'],
#  ['ужас', 'кошмар'],
#  ['только',
#   'славянин',
#   'русофоб',
#   'переходить',
#   'авить',
#   'который',
#   'тысяча',
#   'слава',
#   'род',
#   '🙋🏼☀️'],
#  ['отвратительный',
#   'больший',
#   'корпорация',
#   'должный',
#   'навязывать',
#   'цензура'],
#  ['кал', 'небинарный', 'гендерфлюидный', 'пансексуалы'],
#  ['повесточка', 'славяноненавистник', 'дискриминация', 'лицо'],
#  ['ужс',
#   'сам',
#   'сдавать',
#   'славянин',
#   'квартира',
#   'думать',
#   'никто',
#   'нужный',
#   'чурбан',
#   'только',
#   'славянин',
#   '❤️'],
#  ['помойка',
#   'агрегатор',
#   'диктовать',
#   'кто',
#   'сдавать',
#   'собственность',
#   'дожить',
#   '…'],
#  ['бить', 'х', '**', 'спасти', 'россия', 'квартира', 'только', 'славянин'],
#  ['ограничение',
#   'плохой',
#   'приложение',
#   'плохой',
#   'сервис',
#   'плохой',
#   'стратегия',
#   'развитие',
#   'хотеть',
#   'писать',
#   'объявление',
#   'хотеть'],
#  ['ужасно',
#   'заплатить',
#   '1000р',
#   'размещение',
#   'спустя',
#   'время',
#   'просмотр',
#   '0',
#   'указать',
#   'агенство',
#   'недвижимость',
#   'хотя',
#   'собственник',
#   'указать',
#   'анкета',
#   'мой',
#   'обращение',
#   'поддержка',
#   'полный',
#   'игнора',
#   'рекомендовать'],
#  ['слава', 'род', 'брат', '☀️', 'род', 'слава', '🙋\u200d♂️'],
#  ['многонациональный', 'помойка', 'шлак'],
#  ['отзыв', 'отвратительный', 'сервис', 'работать', 'ужасно'],
#  ['впустить',
#   'страна',
#   'хватить',
#   'диктовать',
#   'хозяин',
#   'квартира',
#   'правило',
#   'сдача'],
#  ['только',
#   'славянуть',
#   'хотеть',
#   'сдавать',
#   'квартира',
#   'русский',
#   'национальность'],
#  ['ущемление',
#   'право',
#   'славянин',
#   'почему',
#   'решать',
#   'собственник',
#   'кто',
#   'именно',
#   'владелец',
#   'сдавать',
#   'квартира'],
#  ['бред',
#   'хотеть',
#   'сдавать',
#   'квартира',
#   'только',
#   'славянин',
#   'какой',
#   'основание',
#   'запрещать'],
#  ['точик',
#   'точик',
#   'ранний',
#   'цыать',
#   'снемалый',
#   'жылье',
#   'намана',
#   'пат',
#   'непонятный',
#   'здать',
#   'здать',
#   'жылье',
#   'встреча',
#   'здатель',
#   'ехать',
#   'часто',
#   'отказ',
#   'патамучтый',
#   'точик',
#   'вернить'],
#  ['неудобство',
#   'пользование',
#   'последний',
#   'время',
#   'стать',
#   'неудобный',
#   'интерфейс'],
#  ['тормозить',
#   'ужас',
#   'тормозить',
#   'поиск',
#   'работать',
#   'фильтр',
#   'работать',
#   'рекомендовать'],
#  ['дискриминация',
#   'претендент',
#   'славянин',
#   'разжигание',
#   'ненависть',
#   'национальный',
#   'почва'],
#  ['против',
#   'дискриминация',
#   'арендодатель',
#   'человек',
#   'вправе',
#   'распоряжаться',
#   'свой',
#   'собственность',
#   'посчитать',
#   'нужный',
#   'число',
#   'выбирать',
#   'арендатор',
#   'жильё'],
#  ['правый',
#   'сдавать',
#   'квартира',
#   'поддерживать',
#   'человек',
#   'который',
#   'иметь',
#   'право',
#   'сам',
#   'выбирать',
#   'кто',
#   'сдавать',
#   'свой',
#   'жильё'],
#  ['отзыв',
#   'ваш',
#   'требование',
#   'прямой',
#   'косвенный',
#   'дискриминация',
#   'усложнять',
#   'жизнь',
#   'весь'],
#  ['держать',
#   'русский',
#   'порваха',
#   'понаставить',
#   'дислайковый',
#   'никто',
#   'мешать',
#   'сдавать',
#   'ваш',
#   'недвижимость',
#   'кто',
#   'либо'],
#  ['славянин', 'дом', 'кто', 'хотеть', 'тот', 'сдавать'],
#  ['повесточка',
#   'добраться',
#   'хотеть',
#   'решать',
#   'делать',
#   'кто',
#   'сдавать',
#   'свой',
#   'квартира',
#   'сегодня',
#   'запрещать',
#   'один',
#   'появиться',
#   'другой',
#   'против',
#   'ограничение'],
#  ['славянин', 'славянин'],
#  ['пока', 'пока'],
#  ['отличный', 'приложение', 'место', 'общество', 'ксенофоб'],
#  ['иметь',
#   'право',
#   'выбор',
#   'кто',
#   'сдавать',
#   'жильё',
#   'пока',
#   'вернуть',
#   'возможность',
#   'выбор',
#   'кто',
#   'сдавать',
#   'жильё',
#   'удалять',
#   'приложение'],
#  ['дебил', 'делать', 'обратно'],
#  ['правильный',
#   'решение',
#   'замучиться',
#   'сам',
#   'человек',
#   'славянский',
#   'внешность',
#   'звонить',
#   'агент',
#   'замучить',
#   'ещё',
#   'штраф',
#   'сказать',
#   'рассмотреть'],
#  ['позорник', 'ущемление', 'право', 'коренной', 'население'],
#  ['дно', 'ловить', 'единица', 'дискриминация'],
#  ['сайт',
#   'разочарование',
#   'единица',
#   'принуждение',
#   'сдавать',
#   'квартира',
#   'кто',
#   'попасть',
#   'единица',
#   'навязывание',
#   'подменный',
#   'номер'],
#  ['жильё', 'хотеть', 'сдавать', 'только', 'славянин'],
#  ['автор',
#   'приложение',
#   'сдавать',
#   'квартира',
#   'только',
#   'славянин',
#   '….',
#   'извиниться'],
#  ['негативный',
#   'отзыв',
#   'свой',
#   'действие',
#   'ограничивать',
#   'право',
#   'собственник',
#   'сдача',
#   'жильё',
#   'хотеть',
#   'хайпануть',
#   'толерантность',
#   'ещё',
#   'втоптать',
#   'грязь',
#   'разница',
#   'кто',
#   'сдавать',
#   'быть',
#   'приходить',
#   'видеть',
#   'человек',
#   'разворачиваться',
#   'человек',
#   'быть',
#   'терять',
#   'время',
#   'риелтор',
#   'также',
#   'быть',
#   'уточнять',
#   'откуда',
#   'обратить',
#   'внимание',
#   'ещё',
#   'усугубить',
#   'ситуация'],
#  ['полный', 'ужас', 'всё', 'агент', 'подменный', 'номер', 'славянин', '...'],
#  ['ужас',
#   'очень',
#   'рекомендовать',
#   'пользоваться',
#   'данные',
#   'приложение',
#   'очень',
#   'предвзятый',
#   'служба',
#   'поддержка'],
#  ['приложение', 'плохо', 'очень', 'плохо'],
#  ['запрещать',
#   'указывать',
#   'национальность',
#   'съёмщик',
#   'приходиться',
#   'отшивать',
#   'телефон',
#   'лично',
#   'тот',
#   'причина',
#   'обидный',
#   'время',
#   'терять'],
#  ['5', 'бал', 'только', 'славянин', 'видеть'],
#  ['просто', 'объяснение', 'причина', 'отказывать', 'кто', 'угодный'],
#  ['кошмар',
#   'каждый',
#   'вправе',
#   'решать',
#   'кто',
#   'сдавать',
#   'жильё',
#   'экономить',
#   'время',
#   'друг',
#   'друг'],
#  ['такой',
#   'толерантность',
#   'зло',
#   'отменить',
#   'дурацкий',
#   'нововведение',
#   '».'],
#  ['словянуть',
#   'сдавать',
#   'квартира',
#   'хотеть',
#   'указывать',
#   'объявление',
#   'только',
#   'славянуть',
#   'шахад',
#   'русуфами',
#   'асланбек',
#   'общаться',
#   'хотеть',
#   'че',
#   'ребята',
#   '?????????'],
#  ['ставить',
#   'один',
#   'звезда',
#   'blm',
#   'тематика',
#   'арендодатель',
#   'вправе',
#   'указывать',
#   'свой',
#   'требование',
#   'сдача',
#   'жильё',
#   'право',
#   'ограничивать'],
#  ['отказаться',
#   'расизм',
#   'расист',
#   'выступать',
#   'ущемление',
#   'право',
#   'национальный',
#   'признак',
#   'унижать',
#   'русский'],
#  ['ограничивать',
#   'свобода',
#   '❗️',
#   'запрет',
#   'указывать',
#   'кто',
#   'хотеть',
#   'кто',
#   'хотеть',
#   'сдавать',
#   'квартира',
#   'ставить',
#   'кол'],
#  ['отзыв', 'понятно'],
#  ['ужасно',
#   'очень',
#   'плохой',
#   'зепрещать',
#   'политика',
#   'неуваженея',
#   'человек',
#   'мерзость'],
#  ['только', 'славянин', 'решать', 'кто', 'быть', 'сдавать', 'квартира'],
#  ['удалять',
#   'отзыв',
#   'устраивать',
#   'мастурбек',
#   'аланбек',
#   'бесплатный',
#   'экскурсия',
#   'город',
#   'россия',
#   'целое',
#   'очередной',
#   'левацкий',
#   'помойка'],
#  ['валита', 'америка', 'толерантность'],
#  ['цензура', 'честной', 'единица', 'цензура'],
#  ['хотеть', 'задавать', 'сам', 'знать'],
#  ['жаль',
#   'поставить',
#   'маленький',
#   'оценка',
#   'приложение',
#   'неудобный',
#   'долго',
#   'загружаться',
#   'другой',
#   'сервис',
#   'намного',
#   'удобный',
#   'быстрый'],
#  ['расизм', 'ненавидеть', 'славянин'],
#  ['тормозить', 'очень', 'смльный', 'тормозить', '12mini'],
#  ['спасибо', 'поднятие', 'тема', 'расизм', 'принятие', 'удар'],
#  ['спасибо',
#   'огромный',
#   'благодарность',
#   'приложение',
#   'борьба',
#   'фашизм',
#   'интеллигентный',
#   'человек',
#   'маленький',
#   'отталкиваться',
#   'национальный',
#   'принадлежность',
#   'человек',
#   'человек',
#   'ранний',
#   'мочь',
#   'сдавать',
#   'квартира',
#   'кто',
#   'хотеть',
#   'просто',
#   'объявление',
#   'никто',
#   'запрещать',
#   'писать',
#   'порядочный',
#   'гражданин',
#   'рф',
#   '».',
#   'надеяться',
#   'выстоять',
#   'волна',
#   'негодование',
#   'невежда',
#   'ксенофоб'],
#  ['скатиться',
#   'связь',
#   'последний',
#   'событие',
#   'советовать',
#   'пользоваться',
#   'данные',
#   'сервис'],
#  ['дно', 'поставить', '1', 'заслужить'],
#  ['☀️', 'слава', 'род', 'славянский', '💪'],
#  ['ужасно',
#   'отвратительный',
#   'работа',
#   'приложение',
#   'тормозить',
#   'вместо',
#   'русский',
#   'язык',
#   'предлагать',
#   'киргизский',
#   'узбекский'],
#  ['ограниченый',
#   'функционал',
#   'приложение',
#   'стать',
#   'славянин',
#   'удалять',
#   'один',
#   'звезда',
#   'компания',
#   'сменить',
#   'регион',
#   'целевой',
#   'аудитория'],
#  ['удалить', 'сдать', 'только', 'славянин', 'переходить', 'авить'],
#  ['удалять', 'рекомендовать', 'данный', 'приложение', 'славянин'],
#  ['диз',
#   'неславянин',
#   'дожить',
#   'приложение',
#   'телефон',
#   'диктовать',
#   'мы',
#   'кто',
#   'сдавать',
#   'квартира'],
#  ['право',
#   'решать',
#   'ужасный',
#   'приложение',
#   'лишь',
#   'кто',
#   'угодить',
#   'русский',
#   'забыть',
#   'очень',
#   'надеяться',
#   'сдуться',
#   '…'],
#  ['лицемер', 'двуличный'],
#  ['решать',
#   'кто',
#   'сдавать',
#   'жильё',
#   'приложение',
#   'пользоваться',
#   'быть',
#   'оно',
#   'нарушать',
#   'мой',
#   'право',
#   'собственник',
#   'жильё',
#   'сдавать',
#   'только',
#   'тот',
#   'кто',
#   'считать',
#   'нужный'],
#  ['глупость',
#   'прийтись',
#   'спрашивать',
#   'национальность',
#   'телефонный',
#   'разговор',
#   'смысл',
#   'просто',
#   'досадный',
#   'неудобство'],
#  ['нестабильный',
#   'приложение',
#   'работать',
#   'сразу',
#   'видно',
#   'делать',
#   'высококлассный',
#   'специалист',
#   'маркетолог'],
#  ['славянин', '1', 'звезда', 'дискриминация', 'русский', 'народ', '!!'],
#  ['плохо', 'очень', 'плохо'],
#  ['право', 'выбор', 'человек', 'разобраться', 'кто', 'сдавать', 'квартира'],
#  ['отвратительный', 'дискриминация', 'русский'],
#  ['запрет',
#   'сдавать',
#   'квартира',
#   'славянин',
#   'уважаемый',
#   'обалдеть',
#   'указывать',
#   'хотеть',
#   'сдать',
#   'свой',
#   'жильё',
#   'исключительно',
#   'славянин',
#   'мастурбек',
#   'названивать',
#   '100',
#   'этот',
#   'товарищ',
#   'иметь',
#   'дело',
#   'вообще',
#   'сдавать',
#   'квартира',
#   'селиться',
#   '10',
#   'человек',
#   'приливный',
#   'квартира',
#   'превращаться',
#   'кусок',
#   'г',
#   '..',
#   'вна',
#   'рекомендовать',
#   'пользоваться',
#   'это',
#   'сервис',
#   'связь',
#   'новый',
#   'политика'],
#  ['дискриминация', 'дискриминация', 'славянин', 'отвратительный'],
#  ['хотеть',
#   'сдавать',
#   'жильё',
#   'зарубежный',
#   'гражданин',
#   'почему',
#   'решать',
#   'скачивать',
#   'авить'],
#  ['кто', 'хотеть', 'тот', 'сдавать', 'кто', 'хотеть', 'тот', 'сдавать'],
#  ['русофоб', 'русофоб'],
#  ['русь',
#   'усрусь',
#   'проходимый',
#   'мимо',
#   'увожать',
#   'присоединяться',
#   'флешмоб',
#   '🤘🏼🤪'],
#  ['ужас', 'квартира', 'хотеть', 'решать', 'кто', 'туда', 'подселять'],
#  ['славянин',
#   'россия',
#   'работать',
#   'русский',
#   'человек',
#   'быть',
#   'сам',
#   'решать',
#   'кто',
#   'сдавать',
#   'квартира',
#   'кто'],
#  ['печаль',
#   'приложение',
#   'удобно',
#   'использование',
#   'регулярно',
#   'зависать',
#   'выкидывать',
#   'поиск',
#   'рекомендовать',
#   'использование'],
#  ['прогиб',
#   'ваш',
#   'прогиб',
#   'десятка',
#   'тысяча',
#   'человек',
#   'прийтись',
#   'чурка',
#   'телефон',
#   'лично',
#   'общаться',
#   'отказать'],
#  ['спасибо', 'славянин'],
#  ['слава', 'вернуть', 'славянин'],
#  ['приложение',
#   'сливать',
#   'дать',
#   'пользователь',
#   'отвратительный',
#   'приложение',
#   'сливать',
#   'дать',
#   'пользователь'],
#  ['чебурек', 'чебурек', 'мочь', 'назвать', 'чебурек'],
#  ['глючный', 'глючный', 'неудобный', 'приложение'],
#  ['позор', 'дискриминация'],
#  ['тупой',
#   'новый',
#   'правило',
#   'почему',
#   'диктовать',
#   'свой',
#   'правило',
#   '?!',
#   'хотеть',
#   'сдавать',
#   'свод',
#   'квартира',
#   'славянин',
#   'мой',
#   'жильё',
#   'кто',
#   'хотеть',
#   'тот',
#   'сдавать'],
#  ['дискриминация', 'ущемление', 'русский', 'дом'],
#  ['россия', 'славянин', 'только', 'славянин'],
#  ['только',
#   'славянин',
#   'иметь',
#   'полный',
#   'право',
#   'решать',
#   'кто',
#   'сдавать',
#   'указывать',
#   'мигрант',
#   'домой',
#   'аул',
#   'пора',
#   'ехать',
#   'квартира',
#   'смотреть',
#   'аренда',
#   'админ',
#   'русофоб',
#   '….',
#   'удалять',
#   'приложение'],
#  ['ах', 'злой', 'печенег'],
#  ['дискриминация', 'единица', 'дискриминация', 'русский'],
#  ['плохо',
#   'работать',
#   'начинать',
#   'писать',
#   'объявление',
#   'появляться',
#   'повесточка',
#   'плохо',
#   'плохо',
#   'славянин',
#   'негде',
#   'жить'],
#  ['тупой',
#   'поступок',
#   'вместо',
#   'бороться',
#   'липовый',
#   'объявление',
#   'несуществующий',
#   'квартира',
#   'решить',
#   'запретить',
#   'славянин',
#   'штоша',
#   'удача'],
#  ['ущемление',
#   'право',
#   'привилегия',
#   'белый',
#   'человек',
#   'иметь',
#   'право',
#   'сдавать',
#   'квартира',
#   'тот',
#   'кто',
#   'хотеть',
#   'культурный',
#   'белый',
#   'человек',
#   'приезжий',
#   'животное',
#   '14',
#   '88'],
#  ['толерантность',
#   'почему',
#   'мочь',
#   'решать',
#   'кто',
#   'хотеть',
#   'сдавать',
#   'квартира'],
#  ['сдать',
#   'квартира',
#   'только',
#   'славянин',
#   'владелец',
#   'знать',
#   'кто',
#   'нужно',
#   'сдавать',
#   'квартира',
#   'сдать',
#   'квартира',
#   'только',
#   'славянин',
#   'личный',
#   'стасян'],
#  ['прощать', 'стать', 'ещё', 'плохой', 'добрый', ':)'],
#  ['кто', 'хотеть', 'тот', 'сдавать', 'ты', 'решать'],
#  ['несоблюдение',
#   'право',
#   'собственник',
#   'ограничивать',
#   'право',
#   'собственник'],
#  ['потворство',
#   'русофобия',
#   'право',
#   'каждый',
#   'человек',
#   'сам',
#   'выбирать',
#   'контрагент',
#   'право',
#   'уничтожить'],
#  ['право', 'сдавать', 'свой', 'жильё', 'кто', 'пожелать', 'против'],
#  ['спасибо',
#   'подписка',
#   'дом',
#   'очень',
#   'нравиться',
#   'возможность',
#   'выбрать',
#   'конкретный',
#   'дом',
#   'ждать',
#   'объявление',
#   'он',
#   'класс'],
#  ['больший', 'молодец', 'долой', 'ксенофобия'],
#  ['славянин', 'стрелочка', 'поворачиваться'],
#  ['нарушение',
#   'право',
#   'свобода',
#   'слово',
#   'выбор',
#   'квартира',
#   'хотеть',
#   'сдавать',
#   'её',
#   'только',
#   'славянин',
#   'мой',
#   'право'],
#  ['удалять', 'сметь', 'указывать', 'кто', 'собственник', 'сдавать', 'жильё'],
#  ['конченый', 'конченый'],
#  ['дискриминация',
#   'дискриминировать',
#   'национальность',
#   'в2021',
#   'год',
#   'дикий',
#   'прощать'],
#  ['спасибо',
#   'прекрасный',
#   'дополнение',
#   'человек',
#   'который',
#   'писать',
#   'всякий',
#   'националистский',
#   'дичь',
#   'выбраться',
#   'сначала',
#   'будка',
#   'свой',
#   'такой',
#   'мозг',
#   'вряд',
#   'сдавать',
#   'славянин'],
#  ['плохой', 'приложение', 'отвратительный'],
#  ['уважать',
#   'свой',
#   'пользователь',
#   'приложение',
#   'цензурировать',
#   'всячески',
#   'притеснять',
#   'ваш',
#   'право',
#   'выбор',
#   'съёмщик',
#   'категорически',
#   'байкотировать',
#   'только',
#   'славянин',
#   'русофоб',
#   '!!'],
#  ['запрет',
#   '..',
#   'сомнительный',
#   'поведение',
#   'владелец',
#   'сервис',
#   '…',
#   'неуважительный',
#   'отношение',
#   'свой',
#   'гражданин'],
#  ['русофобия',
#   'пройти',
#   'против',
#   'нововведение',
#   'напрямую',
#   'затрагивать',
#   'право',
#   'владелец',
#   'жильё',
#   'мой',
#   'соотечественник',
#   'имущество'],
#  ['русофобия',
#   'сказать',
#   'сказать',
#   'русский',
#   'будт',
#   'русский',
#   'ровняться',
#   'доблестный',
#   'русский',
#   'предок'],
#  ['вонять', 'приложение', 'вонять'],
#  ['рейтинг',
#   'вниз',
#   'народ',
#   'запрещать',
#   'опубликовывать',
#   'объявление',
#   'сдаваться',
#   'только',
#   'славянин',
#   'ставить',
#   'один',
#   'звезда'],
#  ['полный',
#   'отстой',
#   '..',
#   'лагаета',
#   'очень',
#   'удобно',
#   'лагаета',
#   'удобный',
#   'большой',
#   'минус'],
#  ['работать',
#   'ранний',
#   'газета',
#   'тот',
#   'работать',
#   'площадка',
#   'никакой',
#   '!!!!'],
#  ['русский', 'зверьё', 'пещера'],
#  ['…',
#   'пу',
#   'толерантность',
#   'решать',
#   'кто',
#   'сдавать',
#   'недвижимость',
#   'черножопый',
#   'пусть',
#   'сидеть',
#   'аулахудалить',
#   'обосанный',
#   'приложение',
#   'сразу',
#   'удача',
#   'помойка'],
#  ['жирный',
#   'минус',
#   'поставить',
#   '5',
#   'звезда',
#   'только',
#   'сам',
#   'знать',
#   'кто'],
#  ['только', 'славянин', 'помойка'],
#  ['0',
#   '10',
#   'хороший',
#   'отзыв',
#   'только',
#   'славянин',
#   'сам',
#   'сдавать',
#   'квартира',
#   'мигрант'],
#  ['тормозить', 'тормозить'],
#  ['спасибо',
#   'сегодня',
#   'узнать',
#   'запретить',
#   'выкладывать',
#   'объявление',
#   'оскорбление',
#   'только',
#   'славянин',
#   '».',
#   'наш',
#   'общество',
#   'должный',
#   'место',
#   'такой',
#   'случай',
#   'оскорбление',
#   'деление',
#   'сделать',
#   'достойный',
#   'шаг',
#   'путь',
#   'этот',
#   'процветание',
#   'ребята'],
#  ['0',
#   'дать',
#   'клиент',
#   'сам',
#   'выбирать',
#   'кто',
#   'быть',
#   'сдавать',
#   'квартира'],
#  ['выгодно',
#   'первый',
#   'звезда',
#   'получать',
#   'бесплатно',
#   'второй',
#   'смочь',
#   'приобрести',
#   'поздний',
#   '799'],
#  ['хватить',
#   'навязывать',
#   'собственник',
#   'иметь',
#   'право',
#   'решать',
#   'кто',
#   'сдавать',
#   'недвижимость'],
#  ['ужасный',
#   'приложение',
#   'ужасный',
#   'сервис',
#   'дискриминация',
#   'русский',
#   'указывать',
#   'распоряжаться',
#   'мой',
#   'собственность'],
#  ['ксенофобия',
#   'славянин',
#   'только',
#   'итак',
#   'однозначно',
#   'плохо',
#   'убого',
#   'писать',
#   'легендарный',
#   'фраза',
#   'сдавать',
#   'стать',
#   'сдавать',
#   'квартира',
#   'хотеть',
#   'всё',
#   'никакой',
#   'левачка',
#   'вышка',
#   'иметь',
#   'никакой',
#   'право',
#   'заставить',
#   'делать',
#   'зато',
#   'быть',
#   'тратить',
#   'время',
#   'зря',
#   'звонок',
#   'беседа',
#   'сдать',
#   'хотеть',
#   'мой',
#   'решение',
#   'зато',
#   'посмотреть',
#   'забавно',
#   'радоваться',
#   'обратить',
#   'внимание',
#   'подавлять',
#   'большинство',
#   'женщина',
#   'левачка',
#   'этот',
#   'запрет',
#   'рада',
#   'лишний',
#   'заткнуть',
#   'мы',
#   'рот',
#   'слабый',
#   'убогий',
#   'получиться',
#   'сдавать',
#   'только',
#   'славянин',
#   'быть',
#   'продолжать',
#   'делать',
#   'жить',
#   'страна',
#   '80',
#   'население',
#   'русский',
#   'правило',
#   'должный',
#   'устанавливать',
#   'русский',
#   'кавказ',
#   'главный',
#   'кавказец',
#   'это',
#   'никто',
#   'поспорить',
#   'чечня',
#   'чеченец',
#   'дагестан',
#   'дагестанец',
#   'никто',
#   'смущать',
#   'дагестан',
#   'прочить',
#   'жить',
#   'старовер',
#   'речь',
#   'заходить',
#   'россия',
#   'подниматься',
#   'невероятный',
#   'вопль',
#   'кроме',
#   'мочь',
#   'хозяин',
#   'свой',
#   'земля',
#   'неправильно',
#   'работать',
#   'ваш',
#   'любимый',
#   'демократия',
#   'власть',
#   'большинство',
#   'принять',
#   'власть',
#   '80',
#   'население',
#   'рф',
#   'спорить',
#   'либо',
#   'возвращаться',
#   'свой',
#   'солнечный',
#   'великий',
#   'аул'],
#  ['сдавать',
#   'славянин',
#   'быть',
#   'сдавать',
#   'отвратительный',
#   'приложение',
#   'компания'],
#  ['дно',
#   'видимо',
#   'подумать',
#   'чурка',
#   'который',
#   'жить',
#   '20',
#   'человек',
#   'один',
#   'комната',
#   'такой',
#   'случай',
#   'раз',
#   'мы',
#   'русский',
#   'делать',
#   'нечего',
#   'спасибо',
#   'выгонять',
#   'страна'],
#  ['нацик',
#   'должный',
#   'страдать',
#   'молодец',
#   'высокий',
#   'технология',
#   'нациковы',
#   'самый',
#   'человек',
#   'лоб',
#   'вешать',
#   'георгиевский',
#   'ленточка'],
#  ['группа',
#   'алиса',
#   'очень',
#   'неудобный',
#   'приложение',
#   'постоянно',
#   'зависать',
#   'часто',
#   'тормозить',
#   'навязывать',
#   'совершенно',
#   'нужно',
#   'исключать',
#   'возможность',
#   'ваш',
#   'выбор'],
#  ['бред',
#   'сдавать',
#   'частный',
#   'собственность',
#   'кто',
#   'хотеть',
#   'только',
#   'тратить',
#   'время',
#   'звонить',
#   'мой',
#   'число',
#   'уходить',
#   'конкурент'],
#  ['шляпа', 'спасибо', 'только', 'славянин'],
#  ['👎🏻👎🏻👎🏻', 'спасибо', 'решить', 'кто', 'быть', 'сдавать', 'жилплощадь'],
#  ['дискриминация', 'лицо', 'идти', 'такой', 'подход', 'около', 'яйцо'],
#  ['спасибо',
#   'спасибо',
#   'нововведение',
#   'телефон',
#   'узнавать',
#   'страна',
#   'арендатор',
#   'непременно',
#   'узнавать',
#   'встреча',
#   '😂'],
#  ['сергей', 'отличный', 'приложение', 'суперудобный', 'функционал'],
#  ['плевать',
#   'покататься',
#   'тот',
#   'кто',
#   'называть',
#   'мороз',
#   'один',
#   'квартира',
#   'третий',
#   'везде',
#   'получить',
#   'ворота',
#   'поворот',
#   'сам',
#   'взвыть',
#   'циан',
#   'гнида',
#   'плохой',
#   'петрополитет'],
#  ['сдавать', 'кто', 'хотеть', 'спасибо', 'предложение'],
#  ['расизм', 'место', 'наш', 'земля'],
#  ['славянин',
#   'принципиально',
#   'воспользоваться',
#   'ваш',
#   'приложение',
#   'сайт',
#   'сдавать',
#   'далёкий',
#   'славянин',
#   '!!!!!!'],
#  ['очень', 'плохо', 'очень', 'плохо'],
#  ['сдавать',
#   'только',
#   'славянин',
#   'квартира',
#   'сдавать',
#   'только',
#   'славянин',
#   'никакой',
#   'указывать',
#   'писать',
#   '!!',
#   'ужасный',
#   'приложение',
#   'весь',
#   'советовать',
#   'авить'],
#  ['ограничение',
#   'сдача',
#   'квартира',
#   'принципиально',
#   'связываться',
#   'тот',
#   'зачастую',
#   'презирать',
#   'тот',
#   'кто',
#   'принадлежать',
#   'небо',
#   'версия',
#   'группа',
#   'алиса'],
#  ['отзыв',
#   'возможно',
#   'новый',
#   'правило',
#   'написание',
#   'объявление',
#   'аренда',
#   'добавить',
#   'арендодатель',
#   'иметь',
#   'право',
#   'отказать',
#   'аренда',
#   'объяснение',
#   'причина',
#   'тратить',
#   'время',
#   'арендатор',
#   'арендодатель',
#   'бессмысленный',
#   'звонок',
#   'равно',
#   'арендодатель',
#   'заселить',
#   'тот',
#   'кто',
#   'захотеть'],
#  ['хороший',
#   'идея',
#   'испортить',
#   'безобразие',
#   'сайт',
#   'приложение',
#   'суть',
#   'являться',
#   'только',
#   'кормушка',
#   'наглый',
#   'глупый',
#   'риелтор',
#   'последний',
#   'нововведение',
#   'ущемлять',
#   'собственник',
#   'сдача',
#   'недвижимость',
#   'право',
#   'полноценно',
#   'обозначить',
#   'свой',
#   'предпочтение',
#   'арендатор'],
#  ['дружно', 'удалить', 'app', 'store', 'русофоб'],
#  ['глючить', 'глючный', 'г', 'панорама', 'хата', 'купить'],
#  ['ужасный', 'приложение', 'решать', 'кто', 'сдавать', 'квартира', 'кто'],
#  ['кек', 'хороший', 'сервис'],
#  ['кыргыз',
#   'приехать',
#   'москва',
#   'ранний',
#   'писать',
#   'квартира',
#   'славянин',
#   'ездить',
#   'писать',
#   'везде',
#   'ездить',
#   'никто',
#   'сдавать',
#   'квартира',
#   'становиться',
#   'тяжело',
#   'вернуть',
#   'пожалуйста',
#   'надпись',
#   'сдавать',
#   'славянин'],
#  ['🤡', 'спасибо', 'мой', 'квартира', 'жить', '10', 'цыган'],
#  ['мёртвый',
#   'приложение',
#   'сюда',
#   'вообще',
#   'заходить',
#   '???',
#   'мёртвый',
#   'приложение',
#   'сюда',
#   'вообще',
#   'заходить',
#   '???'],
#  ['быть',
#   'пользоваться',
#   'другой',
#   'приложение',
#   'американский',
#   'биржа',
#   'правильно',
#   'отреагировать',
#   'ваш',
#   'русофобский',
#   'решение',
#   '15',
#   'стоимость',
#   'акция',
#   'быть',
#   'пользоваться',
#   'яндекс',
#   'недвижимость'],
#  ['кто',
#   'сдавать',
#   'жильё',
#   'личный',
#   'дело',
#   'собственник',
#   'сдавать',
#   'квартира',
#   'только',
#   'славянин',
#   'кто',
#   'сдавать',
#   'полный',
#   'право',
#   'только',
#   'собственник',
#   'вправе',
#   'запрещать'],
#  ['молодец',
#   'правильно',
#   'сделать',
#   'запретить',
#   'расистский',
#   'объявление',
#   'почему',
#   'человек',
#   'забывать',
#   'россия',
#   'многонациональный',
#   'страна'],
#  ['1', 'шляпа'],
#  ['вообще', 'такой', 'националист', 'ненавидеть', 'славянин'],
#  ['навязывать',
#   'свой',
#   'условие',
#   'далёкий',
#   'собственник',
#   'быть',
#   'сдавать',
#   'свой',
#   'жильё',
#   'условие',
#   'который',
#   'навязать',
#   'мой',
#   'право',
#   'сдавать',
#   'свой',
#   'жильё',
#   'удобный',
#   'условие',
#   '👎'],
#  ['кал', 'отвратительный', 'приложение', 'толерастия', 'головной', 'мозг'],
#  ['остановка',
#   'объявление',
#   'разместить',
#   'приложение',
#   'вылетать',
#   'стадия',
#   'регистрация'],
#  ['приложение',
#   'корявый',
#   'грузить',
#   'смартфон',
#   'большинство',
#   'объявление',
#   'фейковый',
#   'либо',
#   'мошенник',
#   'периодически',
#   'виснуть',
#   'функция',
#   'поиск',
#   'недвижимость',
#   'сделать',
#   'пенить',
#   'колода',
#   'короче',
#   'помойка',
#   'советовать'],
#  ['очень',
#   'приложение',
#   'очень',
#   'давать',
#   'помогать',
#   'нуждаться',
#   'человек',
#   'славянский',
#   'внешность'],
#  ['плохо', 'мочь', 'сдать', 'жильё', 'объявление', 'удалять'],
#  ['привет',
#   'славянин',
#   'пока',
#   'цэать',
#   'ле',
#   'паминай',
#   'лихо',
#   'братишкеий',
#   'ле'],
#  ['расист', 'сдавать', 'жильё', 'только', 'белый'],
#  ['пока',
#   'вернуть',
#   'славянин',
#   'оценка',
#   'ребята',
#   'полно',
#   'альтернатива',
#   'этот',
#   'агрегатор',
#   'либо',
#   'директор',
#   'бабуин',
#   'либо',
#   'ку',
#   'ку',
#   'соображалка',
#   'особо',
#   'работать',
#   'человек',
#   'быть',
#   'сдавать',
#   'грач',
#   'хотеть',
#   'время',
#   'поиск',
#   'прийтись',
#   'тратить'],
#  ['хотеть',
#   'заселять',
#   'чурка',
#   'хотеть',
#   'заселять',
#   'вонючий',
#   'чурка',
#   'гора',
#   'помойка'],
#  ['славянин', 'расист'],
#  ['дно', 'забыть', 'спросить', 'кто', 'кто', 'сдавать', 'мой', 'жильё', 'ага'],
#  ['собственность',
#   'мой',
#   'правило',
#   'понимать',
#   'почему',
#   'мой',
#   'деньга',
#   'хотеть',
#   'лишить',
#   'возможность',
#   'взаимодействовать',
#   'чумазый',
#   'агрессивный',
#   'нерусский',
#   'только',
#   'русский',
#   'приложение',
#   'удалить'],
#  ['дискриминация',
#   'молодец',
#   'введение',
#   'анти',
#   'дискриминационный',
#   'мера',
#   'абсолютно',
#   'верный',
#   'правильный',
#   'шаг',
#   'русский',
#   'нациковы',
#   'внимание',
#   'обращать',
#   'только',
#   'интернет',
#   'мочь',
#   'тявкать'],
#  ['многонационал', 'сдать', 'sлavянаm'],
#  ['сходиться', 'отзыв', 'накрутить', 'гугл', 'пэе', '2', '2', '4', '8'],
#  ['удалять', 'удалять', '…', 'годиться'],
#  ['😎👍🏼', 'арендовать', 'небольшой', 'офис', 'успешно'],
#  ['минус', 'требовать', 'разделение', 'приложение', 'black', 'white'],
#  ['только', 'славянин', 'квартира', 'быть', 'решать', 'сдавать', 'славянин'],
#  ['хотеть', 'сдавать', 'квартира', 'славянин', 'миграция'],
#  ['спасибо',
#   'спасибо',
#   'новый',
#   'обновление',
#   'нормальный',
#   'человек',
#   'стать'],
#  ['компания',
#   'скатиться',
#   'заняться',
#   'цензура',
#   'объявление',
#   'арендодатель',
#   'указывать',
#   'свой',
#   'предпочтение',
#   'тратить',
#   'время',
#   'общение',
#   'заранее',
#   'неподходящий',
#   'клиент',
#   'сплошной',
#   'разочарование'],
#  ['онли', 'славянин', 'магил', 'цианчик'],
#  ['вопрос',
#   'разработчик',
#   'арендодатель',
#   'иметь',
#   'право',
#   'выбирать',
#   'кто',
#   'сдавать',
#   'жильё',
#   'кто',
#   'бред'],
#  ['русофобия',
#   'долой',
#   'скажем',
#   'левацкий',
#   'повесточка',
#   'весь',
#   'считать',
#   'сдавать',
#   'квартира',
#   'только',
#   'славянин',
#   'славянский',
#   'страна',
#   'норма',
#   'место',
#   'россия',
#   'россия',
#   'русский',
#   'квартира',
#   'славянин'],
#  ['юк', 'анти', 'русский', 'приложение'],
#  ['русофоб', 'пропагандировать', 'русофобия', 'территория', 'рф', '!!!!'],
#  ['плохо',
#   'сайт',
#   'манипулировать',
#   'тот',
#   'пользоваться',
#   'услуга',
#   'вынуждать',
#   'соглашаться',
#   'невыгодный',
#   'сделка',
#   'называть',
#   'борьба',
#   'дискриминация'],
#  ['зашквара', 'плохой', 'приложение', 'левацкий', 'повестка'],
#  ['1',
#   'нарушать',
#   'воля',
#   'арендодатель',
#   'каждый',
#   'вправе',
#   'решать',
#   'кто',
#   'сдавать',
#   'квартира',
#   'кто'],
#  ['советовать',
#   'смочь',
#   'использовать',
#   'самовыражение',
#   'составление',
#   'объявление',
#   'рекомендовать'],
#  ['отвратительный',
#   'отношение',
#   'арендодатель',
#   'отвратительный',
#   'приложение',
#   'почему',
#   'являться',
#   'суть',
#   'посредник',
#   'арендодатель',
#   'квартиросъёмщик',
#   'решать',
#   'кто',
#   'мочь',
#   'сдавать',
#   'собственность',
#   'кто',
#   'право',
#   'выбирать',
#   'самостоятельно',
#   'съёмщик',
#   'почему',
#   'должный',
#   'тратить',
#   'свой',
#   'нерв',
#   'свой',
#   'время',
#   'объяснять',
#   'почему',
#   'собираться',
#   'сдавать',
#   'квартира',
#   'определённый',
#   'круг',
#   'лицо',
#   'телефон',
#   'хотеть',
#   'тратить',
#   'свой',
#   'время',
#   'нерв',
#   'пока',
#   'быть',
#   'поворачивать',
#   'стрелочка',
#   'только',
#   'один',
#   'сторона',
#   'быть',
#   'сыпаться',
#   'только',
#   'негативный',
#   'отзыв',
#   'пытаться',
#   'угодить',
#   'один',
#   'время',
#   'дискриминировать',
#   'притеснять',
#   'другой'],
#  ['позор', 'настоящий', 'иноагент', 'именно', 'нужно', 'закрывать'],
#  ['таня', 'подобрать', 'жильё', 'проблема', 'около'],
#  ['треш', 'ужасный', 'приложение', 'связь', 'последний', 'обновление'],
#  ['отменять', 'отменять'],
#  ['вон', 'славянин', 'работать'],
#  ['отвратительный',
#   'приложение',
#   'ужасный',
#   'приложение',
#   'удалять',
#   'телефон',
#   'продолжать',
#   'далёкий',
#   'подстилаться',
#   'позор'],
#  ['нация',
#   'человек',
#   'вправе',
#   'сдавать',
#   'квартира',
#   'кто',
#   'захотеть',
#   'отбирать',
#   'право',
#   'распоряжаться',
#   'свой',
#   'собственность',
#   'нимимум',
#   'глупо'],
#  ['дискриминация',
#   'славянин',
#   'дискриминация',
#   'славянин',
#   '?!',
#   'погоня',
#   'псевдотолерантность',
#   '?!'],
#  ['кошмар',
#   'хотеть',
#   'сдавать',
#   'продавать',
#   'жильё',
#   'только',
#   'славянин',
#   'мой',
#   'право',
#   'свободный',
#   'страна',
#   'жить'],
#  ['ужасный',
#   'лаг',
#   'мочь',
#   'банально',
#   'открыть',
#   'объявление',
#   'жутко',
#   'зависать'],
#  ['право',
#   'свобода',
#   'хотеть',
#   'сдавать',
#   'квартира',
#   'кто',
#   'считать',
#   'достойный',
#   'свой',
#   'жильё'],
#  ['глупость',
#   'измена',
#   'политика',
#   'место',
#   'рынок',
#   'недвижимость',
#   'против',
#   'давление',
#   'арендодатель',
#   'каждый',
#   'иметь',
#   'полный',
#   'право',
#   'распоряжаться',
#   'свой',
#   'собственность',
#   'представляться',
#   'правильный'],
#  ['днище',
#   'оборзель',
#   'хотеть',
#   'указывать',
#   'кто',
#   'сдавать',
#   'кто',
#   'сдавать',
#   'мой',
#   'недвижимость'],
#  ['вынудить',
#   'удалить',
#   'приложение',
#   'приложение',
#   'стать',
#   'стабильно',
#   'плохо',
#   'работать',
#   'исправление',
#   'обновление'],
#  ['ужасный',
#   'приложение',
#   'какой',
#   'основание',
#   'решить',
#   'мочь',
#   'указывать',
#   'кто',
#   'сдавать',
#   'жильё',
#   'кто',
#   '??????',
#   'огромный',
#   'количество',
#   'человек',
#   'быть',
#   'поступать',
#   'куча',
#   'звонок',
#   'ненужный',
#   'человек',
#   '!!!!!!'],
#  ['дискриминация',
#   'дискриминация',
#   'русский',
#   'кто',
#   'хотеть',
#   'тот',
#   'сдавать',
#   'квартира'],
#  ['приложение',
#   'ориентировать',
#   'мигрант',
#   'применять',
#   'цензура',
#   'объявление',
#   'соответствовать',
#   'закон',
#   'пользоваться',
#   'другой'],
#  ['ужасно', 'право', 'собственник', 'решать', 'кто', 'сдавать', 'квартира'],
#  ['удалить', 'приложение', 'очень', 'плохо'],
#  ['ужасно', 'отвратительный'],
#  ['супер', '😘😘😘', 'хороший'],
#  ['русофобия', 'пожалуй', 'снести', 'приложение', 'нафиг'],
#  ['право',
#   'человек',
#   'человек',
#   'решать',
#   'кто',
#   'заселять',
#   'квартира',
#   'кто',
#   'квартира',
#   '5',
#   'балл'],
#  ['ужасный',
#   'приложение',
#   'ограничение',
#   'право',
#   'выбор',
#   'кто',
#   'сдавать',
#   'жильё'],
#  ['ущемление',
#   'право',
#   'собственник',
#   'запрещать',
#   'выбирать',
#   'кто',
#   'сдавать',
#   'мой',
#   'собственность',
#   'левацкий',
#   'дрянь',
#   'приложение'],
#  ['диз', 'русофобия', 'должный', 'наказуемый'],
#  ['славянна', 'плохой', 'приложение', 'удобный', 'русски', 'понимать'],
#  ['проверить',
#   'хотеть',
#   'проверить',
#   'настрой',
#   'народ',
#   'молодец',
#   'проверить'],
#  ['черножопый'],
#  ['5',
#   'быть',
#   'только',
#   'славянин',
#   'сдавать',
#   'недвижимость',
#   'только',
#   'славянин',
#   'остальной',
#   'домой'],
#  ['смысл', 'запретить', 'никакой', 'мигрант', 'дом'],
#  ['русофоб', 'приложение', 'удалять'],
#  ['запрет',
#   'какой',
#   'перепуг',
#   'решать',
#   'человек',
#   'кто',
#   'сдавать',
#   'свой',
#   '(!)',
#   'имущество',
#   'попутать',
#   '…'],
#  ['кто',
#   'хотеть',
#   'тот',
#   'сдавать',
#   'портить',
#   'рыночный',
#   'отношение',
#   'свой',
#   'повесточка',
#   'левацкий',
#   'помойка'],
#  ['советовать', 'очень', 'минус', 'который', 'устать', 'писать'],
#  ['словян', 'понять', 'приложение', 'видимо', 'словян'],
#  ['хачприложение', 'сам', 'сдавать', '4урка', '🤣'],
#  ['русский',
#   'человек',
#   'ваш',
#   'приложение',
#   'удалять',
#   'господин',
#   'оторвать',
#   'реальность',
#   'коренной',
#   'население',
#   'свой',
#   'страна',
#   'птичий',
#   'право',
#   'только',
#   'подливать',
#   'масло',
#   'огонь'],
#  ['сдавать', 'обезьяна'],
#  ['убогий',
#   'помойка',
#   ':)',
#   'поддерживать',
#   'народ',
#   'марс',
#   'найти',
#   'славянин',
#   'стыдно',
#   'страна'],
#  ['лагаета', 'открытие', 'приложение', 'лагаета'],
#  ['дно', 'позорище', 'свой', 'толерантность', 'гореть', 'ад'],
#  ['отличный',
#   'инициатива',
#   'оценивать',
#   'порядочность',
#   'человек',
#   'национальный',
#   'принадлежность',
#   'последний',
#   'дело',
#   'поведение',
#   'человек',
#   'зависеть',
#   'раса'],
#  ['молодец',
#   'отличный',
#   'приложение',
#   'маленький',
#   'настоящий',
#   'объявление',
#   'начать',
#   'бороться',
#   'расизм',
#   'просто',
#   'молодец'],
#  ['славянин', 'заступиться', 'славянин', 'получаться', '???'],
#  ['толерантность',
#   'высокий',
#   'уровень',
#   'благодаря',
#   'нововведение',
#   'каждый',
#   'день',
#   'названивать',
#   'моджахед',
#   'мамбета',
#   'желание',
#   'снять',
#   'мой',
#   'квартира',
#   'спасибо',
#   'циан',
#   'толерантность',
#   'надеяться',
#   'толерантный',
#   'отнестись',
#   'оценка',
#   'один',
#   'звезда',
#   'оценка',
#   'хороший'],
#  ['только', 'славянин', 'вернуть', 'возможность', 'дискриминация'],
#  ['сдавать', 'кто', 'хотеть', 'решать'],
#  ['дискриминация',
#   'одуматься',
#   'свободный',
#   'человек',
#   'мочь',
#   'сдавать',
#   'кто',
#   'захотеть',
#   'свой',
#   'жильё'],
#  ['против',
#   'дискриминация',
#   'собственник',
#   'недвижимость',
#   'никто',
#   'советовать',
#   'пользоваться',
#   'услуга',
#   'компания',
#   'который',
#   'хотеть',
#   'запретить',
#   'собственник',
#   'распоряжаться',
#   'имущество',
#   'свой',
#   'усмотрение'],
#  ['плохо', 'работать', 'программа', 'неправильно'],
#  ['негатив', 'рассылка', 'ненужный', 'реклама', 'какой', 'условие', 'ставить'],
#  ['русофоб', 'хотеть', 'сдавать', 'квартира', 'кто', 'попасть', 'выбор'],
#  ['против', 'дискримации', 'русский', 'только', 'славянин'],
#  ['отвратительный',
#   'человек',
#   'иметь',
#   'право',
#   'сдавать',
#   'свой',
#   'жильё',
#   'тот',
#   'кто',
#   'хотеть',
#   'бредовый',
#   'нововведение',
#   'разочаровать'],
#  ['молодец',
#   'поддерживать',
#   'ваш',
#   'позиция',
#   'молодец',
#   'сервис',
#   'приложение',
#   'правда',
#   'хороший'],
#  ['сдать', 'однушко', 'цао', '30', 'пазязь'],
#  ['дискриминировать',
#   'национальность',
#   'приложение',
#   'дискриминировать',
#   'славянин',
#   '21',
#   'ужас',
#   'расизм',
#   'чистый',
#   'вода'],
#  ['плохо',
#   'сказать',
#   'сервис',
#   'достаточно',
#   'только',
#   'реально',
#   'нравиться',
#   'причём',
#   'арендовать',
#   'время',
#   'один',
#   'квартира',
#   'приличный',
#   'сервис',
#   'подобрать',
#   'дозвониться',
#   'мочь',
#   '99',
#   '%!'],
#  ['ужас', 'увидеть', 'свой', 'объявление', 'риелтор'],
#  ['ограничение',
#   'требоваться',
#   'возможность',
#   'указывать',
#   'параметр',
#   'квартиросъёмщик',
#   'животное',
#   'например',
#   'только',
#   'славянин'],
#  ['очень',
#   'европейский',
#   'стать',
#   'ищущий',
#   'человек',
#   'искатель',
#   'быть',
#   'время',
#   'тратить',
#   'поиск',
#   'думать',
#   'ладный',
#   'позвонить',
#   'жильё',
#   'маленький',
#   'деньга',
#   'давать',
#   'маленький',
#   'деньга',
#   'животное',
#   'давать',
#   'они',
#   'прекрасно',
#   'спасибо'],
#  ['👎🏻', 'дно', 'пробить'],
#  ['сдача',
#   'недвижимость',
#   'хозяин',
#   'квартира',
#   'сам',
#   'мочь',
#   'решать',
#   'кто',
#   'сдать',
#   'свой',
#   'помещение',
#   'славянин',
#   'швед',
#   'африканец',
#   'p',
#   's',
#   'скорее',
#   'отзыв',
#   'удалить',
#   'сейчас',
#   'чистить'],
#  ['русофоб', 'дискриминация', 'славянин'],
#  ['тормозить', 'приложение', 'слишком', 'часто', 'виснуть'],
#  ['нормально', 'ужасный', 'приложение'],
#  ['только', 'кафир', 'только', 'кефир'],
#  ['сервис',
#   'уровень',
#   'враг',
#   'народ',
#   'оценка',
#   'поставить',
#   'русский',
#   'который',
#   'сдавать',
#   'собственность',
#   'свой',
#   'страна',
#   'кушать',
#   'подавиться',
#   'враг',
#   'народ'],
#  ['p', 'white', 'lives', 'matter'],
#  ['мошенник', 'списать', 'деньга', 'комиссия', 'объявление', 'выложить'],
#  ['стабильность',
#   'глючить',
#   'детски',
#   '",',
#   'самый',
#   'нужный',
#   'момент',
#   'останиться',
#   'сервис'],
#  ['удалять',
#   'приложение',
#   'ещё',
#   'быть',
#   'указывать',
#   'кто',
#   'делать',
#   'менять',
#   'подгузник',
#   'бан'],
#  ['дискриминация', 'найса', 'ущемлять'],
# ...
#   'данный',
#   'приложение',
#   'давать',
#   'писать',
#   'кто',
#   'хотеть',
#   'сдать',
#   'квартира',
#   'просто',
#   'отвратительный',
#   'приложение'],
#  ['получаться',
#   'ущемление',
#   'хотеть',
#   'сдавать',
#   'квартира',
#   'русский',
#   'хотеть',
#   'указать',
#   'только',
#   'русский',
#   'хотеть',
#   'сдать',
#   'квартира',
#   'индиец',
#   'должный',
#   'указать',
#   'индиец',
#   'вернуть',
#   'функционал',
#   'толераст'],
#  ['сильно',
#   'доверять',
#   'приезжий',
#   '…',
#   'сильно',
#   'доверять',
#   'приезжий',
#   'оставлять',
#   'квартира',
#   'только',
#   'славянин',
#   'достаточно',
#   'обрезать',
#   'нежеланный',
#   'я',
#   'человек',
#   'который',
#   'другой',
#   'культура',
#   'иначе',
#   'голова',
#   'почему',
#   'компания',
#   'решать',
#   'кто',
#   'принимать'],
#  ['дискриминация', 'славянин', 'дискриминация', 'славянин'],
#  ['правило', 'нравиться'],
#  ['1', '5', 'море', 'чёрный', 'риелтор', 'почему', 'это', 'следить'],
#  ['указывать',
#   'только',
#   'русский',
#   'сдавать',
#   'квартира',
#   'дискриминация',
#   '».',
#   'получаться',
#   'ради',
#   'другой',
#   'дискриминировать',
#   'сам',
#   'русский',
#   'интересный',
#   'логика'],
#  ['удалять',
#   'приложение',
#   'спасибо',
#   'право',
#   'выбирать',
#   'кто',
#   'сдавать',
#   'недвижимость',
#   '!!'],
#  ['дизлайк',
#   'приложение',
#   'смочь',
#   'писать',
#   'объявление',
#   'сдать',
#   'квартира',
#   'только',
#   'славянин',
#   'сдавать',
#   'быть',
#   'сдавать',
#   'свой',
#   'квартира',
#   'только',
#   'славянин',
#   'разрешить',
#   'делать',
#   'акцент',
#   'быть',
#   'пользоваться',
#   'другой',
#   'приложение',
#   'прекрасно',
#   'знать',
#   'какой',
#   ':)'],
#  ['ужас',
#   'возомнить',
#   'крутой',
#   'решить',
#   'решать',
#   'человек',
#   'делать',
#   'огрести'],
#  ['ущемление',
#   'право',
#   'пользователь',
#   'очередной',
#   'вид',
#   'прогрессивность',
#   'ущемляться',
#   'право',
#   'другой',
#   'человек',
#   'почему',
#   'пользователь',
#   'решать',
#   'кто',
#   'сдавать',
#   'надеяться',
#   'администрация',
#   'радушно',
#   'приютить',
#   'квартира',
#   'бедный',
#   'мастурбек'],
#  ['ущербный', 'приложение', 'стоить', 'пользоваться', 'это', 'кал'],
#  ['неудобно',
#   'отвратительный',
#   'приложение',
#   'начало',
#   '2000',
#   'х',
#   'крайне',
#   'рекомендовать'],
#  ['против',
#   'дискриминация',
#   'славянин',
#   '!!',
#   'человек',
#   'выбирать',
#   'кто',
#   'хотеть',
#   'сдавать',
#   'квартира',
#   'сервис',
#   'неплохой',
#   'часто',
#   'использовать',
#   'работа',
#   'личный',
#   'цель',
#   'такой',
#   'отношение',
#   'выбор',
#   'каждый',
#   'человек',
#   'кто',
#   'сдавать',
#   'квартира',
#   'кто',
#   'ставить',
#   'вопрос',
#   'адекватность',
#   'администрация',
#   'жить',
#   'вроде',
#   'страна',
#   'свободный',
#   'выбор',
#   'ахахи',
#   '🧐'],
#  ['плохо', 'плохо'],
#  ['недвижимость',
#   'человек',
#   'право',
#   'сдавать',
#   'кто',
#   'хотеть',
#   'ваш',
#   'ребёнок',
#   'прилететь',
#   'обезьяна',
#   'гарантировать'],
#  ['ужасный',
#   'приложение',
#   'ужасный',
#   'приложение',
#   'русофобский',
#   'никто',
#   'рекомендовать',
#   'пользоваться',
#   'это',
#   'приложение'],
#  ['чуркан', 'чуркан'],
#  ['недовольный',
#   'приложение',
#   'плохо',
#   'работакт',
#   'поис',
#   'постоянно',
#   'вылетать',
#   'переход',
#   'карта'],
#  ['дискриминация',
#   'указывать',
#   'распоряжаться',
#   'мой',
#   'имущество',
#   'кто',
#   'сдавать'],
#  ['слишком', 'левый', 'приложение', 'удалить'],
#  ['ужас',
#   'обновление',
#   'перестать',
#   'работать',
#   'меню',
#   'оно',
#   'вообще',
#   'открываться'],
#  ['иметь', 'право', 'сдавать', 'кто', 'хотеть'],
#  ['промахнуться',
#   'собственник',
#   'решить',
#   'кто',
#   'сдавать',
#   'кто',
#   'свой',
#   'нововведение',
#   'только',
#   'занять',
#   'время',
#   'собственник',
#   'создать',
#   'конфликтный',
#   'ситуация',
#   'привлечь',
#   'клиент',
#   'убрать',
#   'тот',
#   'собственно',
#   'сдавать',
#   'жилплощадь',
#   'учёт',
#   'суета',
#   'свой',
#   'нос',
#   'свой',
#   'дело',
#   'работать',
#   'вы',
#   'захотеть',
#   'маленький',
#   'человек'],
#  ['дискриминация', 'кол', 'дискриминация'],
#  ['88', 'только', 'русский'],
#  ['против', 'против'],
#  ['1', 'дискриминация', 'славянин'],
#  ['шляпа',
#   'уйти',
#   'авить',
#   'толерастие',
#   'данный',
#   'сайт',
#   'хотеть',
#   'выбирать',
#   'кто',
#   'сдавать',
#   'квартира',
#   'сразу',
#   'отсеивать',
#   'нерусский',
#   'съёмщик'],
#  ['кстати',
#   'запрещать',
#   'человек',
#   'кто',
#   'сдавать',
#   'собственность',
#   'тот',
#   'страна',
#   'решить',
#   'дать',
#   'полить',
#   'пируэт',
#   'делать'],
#  ['доколе', 'сколько'],
#  ['против', 'дискоиминация', 'против', 'дискриминация', 'славянин'],
#  ['сам',
#   'сделать',
#   'плохой',
#   'указывать',
#   'кто',
#   'национальность',
#   'сдавать',
#   'лола',
#   'окей',
#   'человек',
#   'быть',
#   'ехать',
#   'адрес',
#   'равно',
#   'получить',
#   'отказ',
#   'национальный',
#   'признак',
#   'только',
#   'потратить',
#   'свой',
#   'время',
#   'деньга'],
#  ['no',
#   'to',
#   'the',
#   'nazis',
#   'in',
#   'the',
#   '21st',
#   'century',
#   'скачать',
#   'приложение',
#   'только',
#   'написать',
#   'отзыв',
#   '!)',
#   'весь',
#   'ограниченный',
#   'малодушный',
#   'человек',
#   'оставлять',
#   'негативный',
#   'отзыв',
#   'связь',
#   'последний',
#   'обновление',
#   'позволять',
#   'писать',
#   'только',
#   'русский',
#   'славянин',
#   'обновление',
#   'заставлять',
#   'насильно',
#   'сдавать',
#   'ваш',
#   'прямой',
#   'смысл',
#   'прокурить',
#   'грязный',
#   'квартира',
#   'ковёр',
#   'стена',
#   'древний',
#   'мебель',
#   'неадекватный',
#   'цена',
#   'кто',
#   'либо',
#   'кроме',
#   'русский',
#   'какой',
#   'узкий',
#   'мышление',
#   'обладать',
#   'воспринимать',
#   'мир',
#   'такой',
#   'образ',
#   '??',
#   'сожаление',
#   'такой',
#   'человек',
#   'жизнь',
#   'помочь',
#   'такой',
#   'глупость',
#   'быть',
#   'передавать',
#   'поколение',
#   'поколение',
#   'просто',
#   'желать',
#   'конкретно',
#   'неадекватный',
#   'представитель',
#   '),',
#   'поехать',
#   'нацистский',
#   'лицо',
#   'закрывать',
#   'дверь',
#   'слово',
#   'no',
#   'russians',
#   '”.',
#   'хотя',
#   'вероятно',
#   'такой',
#   'человек',
#   'кроме',
#   'свой',
#   'вонючий',
#   'ипотечный',
#   'квартира',
#   'никуда',
#   'ездить',
#   '!))',
#   'касаться',
#   'остальной',
#   'адекватный',
#   'русский',
#   'жаль',
#   'такой',
#   'основополагающий',
#   'принцип',
#   'человечность',
#   'недоступный',
#   'считать',
#   'норма',
#   'судить',
#   'человек',
#   'национальный',
#   'расовый',
#   'принадлежность',
#   'нежели',
#   'человеческий',
#   'качество',
#   'приложение',
#   'ставить',
#   '5',
#   'звезда',
#   'пользоваться',
#   'весь',
#   'адекватный',
#   'человек',
#   'любой',
#   'национальность',
#   'раса',
#   'мир',
#   'добро'],
#  ['ало',
#   'славянин',
#   'сдавать',
#   'холупа',
#   'кто',
#   'хотеть',
#   'вообще',
#   'право',
#   'бесспорный',
#   'ныть',
#   'дискриминация',
#   '»,',
#   'ваш',
#   'объявление',
#   'являться',
#   'дискриминация',
#   'нравиться',
#   'обижать',
#   'человек',
#   'признак',
#   'который',
#   'человек',
#   'мочь',
#   'повлиять',
#   'циан',
#   'респект'],
#  ['отнимать',
#   'свобода',
#   'хотеть',
#   'сдавать',
#   'квартира',
#   'только',
#   'славянин',
#   'запретить',
#   'следовательно',
#   'опускать',
#   'петушатня',
#   'переходить',
#   'конкурент'],
#  ['ужас',
#   'кто',
#   'хотеть',
#   'быть',
#   'сдавать',
#   'сам',
#   'сдавать',
#   'свой',
#   'квартира',
#   'кто',
#   'хотеть'],
#  ['цензура',
#   'мой',
#   'личный',
#   'право',
#   'нация',
#   'сдавать',
#   'жильё',
#   'продавать',
#   'запомнить',
#   'только',
#   'славянин',
#   '!»'],
#  ['гнилой',
#   'приложение',
#   'непродуманный',
#   'правило',
#   'бежать',
#   'рассадник',
#   'толерантность',
#   'авить'],
#  ['только', 'славянин', 'только', 'славянин'],
#  ['рассадник',
#   'мошенник',
#   'риэлтер',
#   'куча',
#   'фейковый',
#   'объявление',
#   'сбор',
#   'контактный',
#   'данные',
#   'покупатель',
#   'жалоба',
#   'реагировать'],
#  ['чистить',
#   'база',
#   'очень',
#   'старый',
#   'актуальный',
#   'объявление',
#   'звонить',
#   'давно',
#   'продать',
#   'сдать',
#   'объявление',
#   'висеть',
#   'год'],
#  ['надёжный', 'житель', 'подобрать', 'неадекват', 'мой', 'квартира'],
#  ['бесполезный', 'штука', 'давать', 'пока'],
#  ['русский',
#   'иметь',
#   'право',
#   'сдавать',
#   'только',
#   'русский',
#   'нравиться',
#   'пусть',
#   'собственник',
#   'персонал',
#   'шарага',
#   'валить',
#   'вон',
#   'россия'],
#  ['славянин', 'сдавать', 'только', 'славянин'],
#  ['дискриминация', 'славянин', 'дискриминация', 'славянин'],
#  ['понравиться',
#   'политика',
#   'дескриминация',
#   'понравиться',
#   'политика',
#   'дискриминация',
#   'последний',
#   'обновление'],
#  ['право',
#   'выбор',
#   'давать',
#   'выбирать',
#   'кто',
#   'хотеть',
#   'сдавать',
#   'собственность',
#   'авить',
#   'намного',
#   'просмотр'],
#  ['слава', 'немножко', 'славянский', 'ненависть', 'дискриминация'],
#  ['расист', 'против', 'дискриминация', 'славянин'],
#  ['тип',
#   'дискриминация',
#   'нарушение',
#   'право',
#   'владелец',
#   'недвижимость',
#   'решать',
#   'кто',
#   'сдавать',
#   'аренда',
#   'кто',
#   'поход',
#   'менеджер',
#   'немного',
#   'догонять',
#   'это',
#   'просто',
#   'немного',
#   'усложнить',
#   'процесс',
#   'изменение',
#   'суть',
#   'любой',
#   'случай',
#   'хозяин',
#   'хотеть',
#   'видеть',
#   'лицо',
#   'национальность',
#   'который',
#   'называть',
#   'равно',
#   'сдать'],
#  ['дно', 'толерантный', 'помойка', 'дискриминировать', 'русский', 'народ'],
#  ['сдавать', 'квартира', 'кто', 'хотеть', 'пробить', 'дно'],
#  ['компания',
#   'плевать',
#   'пользователь',
#   'дикость',
#   'компания',
#   'думать',
#   'навязывать',
#   'свой',
#   'очень',
#   'важный',
#   'мнение',
#   'вопрос',
#   'распоряжаться',
#   'человек',
#   'свой',
#   'собственность',
#   'уходить',
#   'площадка',
#   'надеяться',
#   'другой',
#   'пользователь',
#   'перестать',
#   'пользоваться',
#   'сервис',
#   'откровенно',
#   'плевать'],
#  ['россия',
#   'убрать',
#   'пункт',
#   'только',
#   'славянин',
#   'получить',
#   'плохой',
#   'отзыв',
#   'сдача',
#   'квартира',
#   'только',
#   'белый'],
#  ['глупый', 'нововведение', 'вернуть', 'прежний', 'опция'],
#  ['приложение',
#   'ужасный',
#   'никакой',
#   'толерантность',
#   'приложение',
#   'ужасный',
#   'никакой',
#   'толерантность'],
#  ['ограничивать', 'аренда', 'давать', 'сдавать', 'жильё', 'свой', 'условие'],
#  ['левак',
#   'поганый',
#   'никто',
#   'вправе',
#   'собственник',
#   'диктовать',
#   'кто',
#   'сдавать',
#   'квартира'],
#  ['дискриминация',
#   'коренной',
#   'население',
#   'слава',
#   'русь',
#   'слава',
#   'род',
#   'славянский'],
#  ['отвратительный',
#   'внутренний',
#   'политика',
#   'иметь',
#   'право',
#   'решать',
#   'кто',
#   'сдавать',
#   'мой',
#   'собственность',
#   'человек',
#   'деньга',
#   'отдать',
#   'деньга',
#   'человек',
#   '!?',
#   'ваш',
#   'русофобия',
#   'вынуждать',
#   'оценивать',
#   'ваш',
#   'приложение',
#   'только'],
#  ['отвратительный', 'пользоваться'],
#  ['клиентоориентировать',
#   'сервис',
#   'очень',
#   'плохо',
#   'указать',
#   'хотеть',
#   'сдать',
#   'квартира',
#   'русский',
#   'человек',
#   'славянин',
#   'написывать',
#   'названивать',
#   '20',
#   '30',
#   'человек',
#   'день',
#   'нормально',
#   'говорящий',
#   'русский',
#   'язык',
#   'ужас',
#   'снять',
#   'объявление'],
#  ['наташка', 'приложение', 'дно', 'ущемлять', 'право', 'русский', 'народ'],
#  ['сдавать', 'кто', 'хотеть', 'решить', 'указывать'],
#  ['россия', 'праветь', 'дать', 'бог', 'ваш', 'акция', 'рейтинг', 'обвалиться'],
#  ['че',
#   'ху',
#   '..',
#   'какой',
#   'черта',
#   'ставить',
#   'критерий',
#   'только',
#   'славянин',
#   '»?',
#   'че',
#   'долбануться',
#   'человек',
#   'право',
#   'выбирать',
#   'жить',
#   'квартира',
#   'нормальный',
#   'человек',
#   '🐒',
#   'всякий',
#   'таджик',
#   'даги',
#   'тд',
#   'удалять',
#   'приложение'],
#  ['очень',
#   'решение',
#   'циан',
#   'тот',
#   'кто',
#   'сдавать',
#   'мой',
#   'квартира',
#   'казаться',
#   'теряться',
#   'смысл',
#   'наличие',
#   'данный',
#   'приложение'],
#  ['ужас', 'приложение', 'биомусор'],
#  ['качать', 'вернуть', 'убрать'],
#  ['ущемление',
#   'право',
#   'арендодатель',
#   'собственник',
#   'право',
#   'выбирать',
#   'кто',
#   'сдавать',
#   'недвижимость',
#   'простой',
#   'посредник',
#   'брать',
#   'лишний'],
#  ['сервис',
#   'стать',
#   'очень',
#   'неудобный',
#   'вынудить',
#   'общаться',
#   'человек',
#   'который',
#   'общаться',
#   'хотеть',
#   'квартира',
#   'заведомо',
#   'сдать',
#   'тратить',
#   'мой',
#   'время',
#   'время',
#   'соискатель',
#   'жильё'],
#  ['что',
#   'хотеть',
#   'сдать',
#   'квартира',
#   'благодаря',
#   'циан',
#   'мочь',
#   'осуществить',
#   'второй',
#   'месяц',
#   'приходить',
#   'один',
#   'маргинал',
#   'вредитель',
#   'дикарь'],
#  ['отработать',
#   'материал',
#   'приложение',
#   'испортиться',
#   'окончательно',
#   'хотеться',
#   'пользоваться',
#   'ваш',
#   'приложениемвсего',
#   'хороший'],
#  ['удобно',
#   'удобный',
#   'приложение',
#   'особенно',
#   'обозначение',
#   'курсор',
#   'именно',
#   'хотеть',
#   'рассмотреть',
#   'жильё'],
#  ['стать',
#   'плохой',
#   'нововведение',
#   'циан',
#   'писать',
#   'национальность',
#   'арендатор',
#   'удалить',
#   'описание',
#   'посыпаться',
#   'уйма',
#   'звонок',
#   'всякий',
#   'национальность',
#   'который',
#   'называть',
#   'число',
#   'потрусски',
#   'вообще',
#   'говорить',
#   'страшно',
#   'циан',
#   'выкладывать',
#   'встречаться',
#   'непонятно',
#   'шерстяной',
#   'горький',
#   'опыт',
#   'этот',
#   'обезьяна',
#   'разносить',
#   'оставлять',
#   'хлам',
#   'кишлак'],
#  ['обновление', 'ужас', 'уходить'],
#  ['очень',
#   'ограничивать',
#   'базовый',
#   'человеческий',
#   'право',
#   'имущество',
#   'сдавать',
#   'тот',
#   'кто',
#   'хотеть'],
#  ['комментарий',
#   '..',
#   'свой',
#   'квартира',
#   'сдавать',
#   'черножопый',
#   'сколько',
#   'хотеть',
#   'нормальный',
#   'человек',
#   'дискриминировать'],
#  ['только',
#   'славянин',
#   'циан',
#   'решать',
#   'кто',
#   'сдавать',
#   'личный',
#   'жильё',
#   'кто',
#   'циан',
#   'сдать',
#   'славянин',
#   'другой',
#   'народ',
#   'только',
#   'время',
#   'потерять',
#   'поиск'],
#  ['сдавать', 'кто', 'захотеть', 'идти', 'х', '…'],
#  ['обращение',
#   'русский',
#   'народ',
#   'че',
#   'устроить',
#   'приложение',
#   'площадка',
#   'который',
#   'пользователь',
#   'выставлять',
#   'свой',
#   'квартира',
#   'продажа',
#   'аренда',
#   'мочь',
#   'сдавать',
#   'только',
#   'обезьяна',
#   'пффф',
#   'такой',
#   'приложение',
#   'нужно',
#   '😉.',
#   'сказать',
#   'этот',
#   'приложение',
#   'место',
#   'россия',
#   'продвигать',
#   'свой',
#   'приложение',
#   'калказе',
#   'прочий',
#   'аул',
#   'пусть',
#   'обезьянка',
#   'сдавать',
#   'друг',
#   'друг',
#   'хотеть',
#   'хотятрусский',
#   'сдавать',
#   'обезьянампока',
#   'пока',
#   'крыса',
#   '🐀🐀🐀'],
#  ['сдавать',
#   'кто',
#   'хотеть',
#   'иметь',
#   'право',
#   'отказывать',
#   'нравиться',
#   'человек'],
#  ['привет',
#   'страна',
#   'победить',
#   'нацизм',
#   'сервис',
#   'хороший',
#   'фильтр',
#   'удобный',
#   'работать',
#   'нарекание',
#   'спасибо'],
#  ['приложение',
#   'нацист',
#   'писать',
#   'объявление',
#   'сдавать',
#   'квартира',
#   'только',
#   'хач',
#   'чурка',
#   'удалять'],
#  ['риелтор',
#   'вместо',
#   'убирать',
#   'предпочтение',
#   'кто',
#   'сдавать',
#   'убрать',
#   'возможность',
#   'выставлять',
#   'риелтор',
#   'объявление',
#   'этот',
#   'профессия',
#   'давно',
#   'изжить',
#   'отравлять',
#   'рынок'],
#  ['отвратительный',
#   'сервис',
#   'должный',
#   'указывать',
#   'кто',
#   'должный',
#   'сдавать',
#   'квартира',
#   'считать',
#   'только',
#   'право',
#   'решать',
#   'собственность',
#   'хотеть',
#   'сдавать',
#   'квартира',
#   'только',
#   'определённый',
#   'национальность',
#   'мой',
#   'право',
#   'надеяться',
#   'сервис',
#   'массово',
#   'байкотировать'],
#  ['уронить', 'рейтинг', 'наш', 'дело', 'кто', 'сдавать'],
#  ['толерантненький',
#   'хотеть',
#   'квартира',
#   'сдавать',
#   'только',
#   'славянин',
#   'почему',
#   'мочь',
#   'описание',
#   'указывать',
#   '??',
#   'квартира',
#   'сдавать',
#   'кто',
#   'хотеть'],
#  ['дискриминация', 'славянин', 'против', 'дискриминация', 'славянин'],
#  ['дискриминация',
#   'решать',
#   'кто',
#   'сдавать',
#   'быть',
#   'ипотека',
#   'выплачивать',
#   'хорёк',
#   'позорный'],
#  ['приложение',
#   'удаление',
#   'иметь',
#   'право',
#   'сдавать',
#   'квартира',
#   'кто',
#   'угодный',
#   'славянин',
#   'турок',
#   'таджик',
#   'идти',
#   'пенить',
#   'свой',
#   'ограничение'],
#  ['писать',
#   'только',
#   'славянин',
#   'значит',
#   'быть',
#   'пользоваться',
#   'другой',
#   'аналогичный',
#   'площадка'],
#  ['дискриминация',
#   'давать',
#   'сдавать',
#   'квартира',
#   'славянин',
#   'блокировать',
#   'аккаунт',
#   'нужно',
#   'квартира',
#   'держать',
#   '20',
#   'мастурбек',
#   'хотеть',
#   'сдавать',
#   'квартира',
#   'славянский',
#   'парк'],
#  ['русофоб', 'каждый', 'должный', 'выбор', 'кто', 'сдать', 'квартира'],
#  ['национальный',
#   'политика',
#   'кто',
#   'хотеть',
#   'тот',
#   'сдавать',
#   'свой',
#   'жильё',
#   'мой',
#   'право',
#   'собственник'],
#  ...]

# %%
plt.figure(figsize=(16, 8))
plt.hist([len(x) for x in tokenized_reviews], bins=np.arange(0, 130, 2), rwidth=1)
plt.grid()
plt.title("Количество слов в отзыве (после очистки от стоп-слов)")
plt.xticks(np.arange(0, 130, 10))
plt.show()

# %%
POS_arr = []
for r in tokenized_reviews:
    POS_arr += [extract_POS(x) for x in r]

# %%
pos_counter = Counter(POS_arr)

# %%
ntop = len(pos_counter)
xs = np.arange(len(pos_counter))
ys = [y for x, y in pos_counter.most_common(ntop)][::-1]
labels = [x for x, y in pos_counter.most_common(ntop)][::-1]

plt.figure(figsize=(16, 8))
plt.title("Распределение слов по частям речи")

plt.barh(xs, ys)
plt.yticks(xs, labels=[x + "" for x in labels])
plt.ylabel("Labels")
plt.show()

# %% [markdown]
# Расшифровка тэгов:
# https://pymorphy2.readthedocs.io/en/stable/user/grammemes.html#grammeme-docs

# %% [markdown]
# ### Считаем частоты  n-грамм

# %%
def make_n_grams(arr, n, sep=" "):
    return [sep.join(arr[i:i+n]) for i in range(len(arr) - min(len(arr), n) + 1)]

# %%
N = 4

# %%
n_grams = defaultdict(list)
for tokens in tokenized_reviews:
    for i in range(1, N + 1):
        n_grams[i] += make_n_grams(tokens, i)

# %%
counters = {}
for key, value in n_grams.items():
    counters[key] = Counter(value)

# %%
ncols = 1
nrows = math.ceil(N / ncols)
ntop = 30

fig, axs = plt.subplots(figsize=(10 * ncols, 10 * nrows), ncols=ncols, nrows=nrows)

keys = []

for i, key in enumerate(counters.keys()):
    ax = axs.reshape(-1)[i]
    xs = np.arange(ntop)
    ys = [y for x, y in counters[key].most_common(ntop)][::-1]
    labels = [x for x, y in counters[key].most_common(ntop)][::-1]
    ax.grid()
    ax.barh(xs, ys)
    ax.set_yticks(xs)
    ax.set_yticklabels(labels, rotation=0)

plt.show()

# %% [markdown]
# ### То же самое, но с нормализацией

# %%
n_grams = defaultdict(list)
for tokens in normalized_reviews:
    for i in range(1, N + 1):
        n_grams[i] += make_n_grams(tokens, i)

# %%
counters = {}
for key, value in n_grams.items():
    counters[key] = Counter(value)

# %%
ncols = 1
nrows = math.ceil(N / ncols)
ntop = 30

fig, axs = plt.subplots(figsize=(10 * ncols, 10 * nrows), ncols=ncols, nrows=nrows)

keys = []

for i, key in enumerate(counters.keys()):
    ax = axs.reshape(-1)[i]
    xs = np.arange(ntop)
    ys = [y for x, y in counters[key].most_common(ntop)][::-1]
    labels = [x for x, y in counters[key].most_common(ntop)][::-1]
    ax.grid()
    ax.barh(xs, ys)
    ax.set_yticks(xs)
    ax.set_yticklabels(labels, rotation=0)

plt.show()

# %% [markdown]
# ## Некоторые примеры

# %%
examples = [
    "славянин славянин",
    "дискриминация славянин дискриминация славянин"
]

dct = {x:[] for x in examples}

for i, x in enumerate(normalized_reviews):
    key = " ".join(x)
    if key in examples:
        dct[key].append(reviews[i])
        
for key, value in dct.items():
    print(key)
    for x in value:
        print("\t- " + x)
    print("---")
# Out:
# славянин славянин
# 	- славянам от славян
# 	- за славян за славян
# 	- за славян за славян
# 	- славян славян
# 	- за славян за славян
# 	- за славян за славян
# 	- за славян за славян
# 	- славяне славяне
# ---
# дискриминация славянин дискриминация славянин
# 	- дискриминация славян дискриминация славян
# 	- дискриминация славян дискриминация славян
# 	- дискриминация славян дискриминация славян
# 	- дискриминация славян дискриминация славян
# 	- дискриминация славян дискриминация славян
# 	- дискриминация славян! дискриминация славян!
# ---

# %% [markdown]
# ## Анализ тональности
# Как в https://habr.com/ru/post/472988/

# %%
# !pip3 install textblob
# Out:
# Requirement already satisfied: textblob in /Users/ssheypak/newenv/lib/python3.9/site-packages (0.17.1)
# Requirement already satisfied: nltk>=3.1 in /Users/ssheypak/newenv/lib/python3.9/site-packages (from textblob) (3.5)
# Requirement already satisfied: click in /Users/ssheypak/newenv/lib/python3.9/site-packages (from nltk>=3.1->textblob) (7.1.2)
# Requirement already satisfied: joblib in /Users/ssheypak/newenv/lib/python3.9/site-packages (from nltk>=3.1->textblob) (0.17.0)
# Requirement already satisfied: regex in /Users/ssheypak/newenv/lib/python3.9/site-packages (from nltk>=3.1->textblob) (2020.10.28)
# Requirement already satisfied: tqdm in /Users/ssheypak/newenv/lib/python3.9/site-packages (from nltk>=3.1->textblob) (4.51.0)

# %%
from textblob import TextBlob

# %%
sentence = '''The platform provides universal access to the world's best education, partnering with top universities and organizations to offer courses online.'''

analysisPol = TextBlob(sentence).polarity
analysisSub = TextBlob(sentence).subjectivity

analysisPol,analysisSub
# Out:
# (0.5, 0.26666666666666666)

# %%
sentence = '''Всё очень плохо я так больше не могу'''

analysisPol = TextBlob(sentence).polarity
analysisSub = TextBlob(sentence).subjectivity

analysisPol,analysisSub
# Out:
# (0.0, 0.0)
