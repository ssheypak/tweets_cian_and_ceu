# %% [markdown]
# ### Загружаем текст и ищем, по какому символу разбить

# %%
import pandas as pd
import matplotlib.pyplot as plt
import pandas as pd

from collections import Counter

# %%
db = pd.read_csv("../data/daily_app_reviews_appfollow_202203241835.csv")

# %%
db.head()
# Out:
#                                            v_content platform      v_date
# 0  Обнаглевшие риелторы при содействии администра...  android  2021-12-12
# 1  Отвратительный дизайн интерфейсов Много старых...  android  2021-12-12
# 2  Приложение лагает очень маленькая база по выбо...  android  2021-12-12
# 3  Надеюсь акции этой компании обвалятся а сама о...  android  2021-12-12
# 4  Два раза удалили отзыв молодцы так держать Все...  android  2021-12-12

# %%
fig, axs = plt.subplots(figsize=(18, 9), nrows=1, ncols=1)

db["v_date"].sort_values().hist()
plt.xticks(rotation=70)
plt.show()

# %%
reviews = db[(
    (db["v_date"] >= "2021-12-06") &
    (db["v_date"] <= "2021-12-12"))
]["v_content"].tolist()

# %%
reviews[:5]
# Out:
# ['Обнаглевшие риелторы при содействии администрация блочат объявления частников Вместо совершенствования оболочки компания тратит силы играя с пользователями в толерастию',
#  'Отвратительный дизайн интерфейсов Много старых объявлений Тех поддержка никогда не отвечает Не рекомендую',
#  'Приложение лагает очень маленькая база по выбору Другие агрегаторы дают больше выбора',
#  'Надеюсь акции этой компании обвалятся а сама она обанкротится Циан проводит очень подлую политику',
#  'Два раза удалили отзыв молодцы так держать Всеровно ваш сервис дрянь одни риелторы выходят на связь']

# %%
reviews = [x.strip().lower() for x in reviews]

# %%
reviews[:5]
# Out:
# ['обнаглевшие риелторы при содействии администрация блочат объявления частников вместо совершенствования оболочки компания тратит силы играя с пользователями в толерастию',
#  'отвратительный дизайн интерфейсов много старых объявлений тех поддержка никогда не отвечает не рекомендую',
#  'приложение лагает очень маленькая база по выбору другие агрегаторы дают больше выбора',
#  'надеюсь акции этой компании обвалятся а сама она обанкротится циан проводит очень подлую политику',
#  'два раза удалили отзыв молодцы так держать всеровно ваш сервис дрянь одни риелторы выходят на связь']

# %%
from collections import defaultdict
import matplotlib.pyplot as plt
import math
import numpy as np

# %%
plt.figure(figsize=(16, 8))
plt.hist([len(x) for x in reviews], bins=np.arange(0, 1000, 20), rwidth=1)
plt.grid()
plt.title("Количества в букв в отзывах")
plt.xticks(np.arange(0, 1000, 20), rotation=90)
plt.show()

# %% [markdown]
# ### Пробуем разбить отзывы на предложения.

# %%
import nltk
# nltk.download("punkt")

# %%
from nltk.tokenize import sent_tokenize

# %%
len_sorted_reviews = sorted(reviews, key=lambda x: len(x), reverse=True)

# %%
longest_review = len_sorted_reviews[1]

# %%
len_sorted_reviews[-10:]
# Out:
# ['фу', 'фу', 'na', 'na', 'na', 'na', 'из', 'na', 'ня', 'о']

# %%
longest_review
# Out:
# 'итак однозначно плохо и убого то что теперь нельзя писать легендарную фразу я как не сдавал так и не стану сдавать им квартиру  не хочу и всё и никакая левачка из вышки не может и не имеет никакого права заставить меня этого не делать зато они теперь будут тратить время зря на звонки и беседы ведь им я не сдам потому что не хочу и это моё решение зато посмотрите как забавно радуются обратите внимание  подавляющее большинство женщины левачки этому запрету они рады лишний раз заткнуть нам рот они слабы и убоги и ничего у них не получится а я как сдавал только славянам так и буду продолжать это делать я живу в стране где  населения  русские и правила здесь должны устанавливать русские на кавказе главные кавказцы с этим никто не поспорит в чечне  чеченцы в дагестане  дагестанцы и никого не смущает что в том же дагестане между прочим живут староверы но когда речь заходит о россии  поднимаются невероятные вопли все кроме нас могут быть хозяевами своей земли и это неправильно так же работает ваша любимая демократия  власть большинства вот и примите власть  населения рф и не спорьте с ней либо возвращайтесь в свои солнечные великие аулы'

# %%
sent_tokenize(longest_review.replace(".", "."))
# Out:
# ['итак однозначно плохо и убого то что теперь нельзя писать легендарную фразу я как не сдавал так и не стану сдавать им квартиру  не хочу и всё и никакая левачка из вышки не может и не имеет никакого права заставить меня этого не делать зато они теперь будут тратить время зря на звонки и беседы ведь им я не сдам потому что не хочу и это моё решение зато посмотрите как забавно радуются обратите внимание  подавляющее большинство женщины левачки этому запрету они рады лишний раз заткнуть нам рот они слабы и убоги и ничего у них не получится а я как сдавал только славянам так и буду продолжать это делать я живу в стране где  населения  русские и правила здесь должны устанавливать русские на кавказе главные кавказцы с этим никто не поспорит в чечне  чеченцы в дагестане  дагестанцы и никого не смущает что в том же дагестане между прочим живут староверы но когда речь заходит о россии  поднимаются невероятные вопли все кроме нас могут быть хозяевами своей земли и это неправильно так же работает ваша любимая демократия  власть большинства вот и примите власть  населения рф и не спорьте с ней либо возвращайтесь в свои солнечные великие аулы']

# %%
sent_tokenize(longest_review.replace(".", " . "))
# Out:
# ['итак однозначно плохо и убого то что теперь нельзя писать легендарную фразу я как не сдавал так и не стану сдавать им квартиру  не хочу и всё и никакая левачка из вышки не может и не имеет никакого права заставить меня этого не делать зато они теперь будут тратить время зря на звонки и беседы ведь им я не сдам потому что не хочу и это моё решение зато посмотрите как забавно радуются обратите внимание  подавляющее большинство женщины левачки этому запрету они рады лишний раз заткнуть нам рот они слабы и убоги и ничего у них не получится а я как сдавал только славянам так и буду продолжать это делать я живу в стране где  населения  русские и правила здесь должны устанавливать русские на кавказе главные кавказцы с этим никто не поспорит в чечне  чеченцы в дагестане  дагестанцы и никого не смущает что в том же дагестане между прочим живут староверы но когда речь заходит о россии  поднимаются невероятные вопли все кроме нас могут быть хозяевами своей земли и это неправильно так же работает ваша любимая демократия  власть большинства вот и примите власть  населения рф и не спорьте с ней либо возвращайтесь в свои солнечные великие аулы']

# %%
sentenced_reviews = []

for review in reviews:
    sentenced_reviews += sent_tokenize(review.replace(".", " . "))

# %%
def has_alpha(x):
    return len(x) > 0 and max([l.isalpha() for l in x])

# %%
len(reviews), len(sentenced_reviews), len([x for x in sentenced_reviews if has_alpha(x)])
# Out:
# (10782, 10782, 10782)

# %%
reviews = [x for x in sentenced_reviews if has_alpha(x)]

# %%
comma_split_reviews = []

for review in reviews:
    comma_split_reviews += review.split(",")

# %%
len(reviews), len(comma_split_reviews)
# Out:
# (10782, 10782)

# %%
reviews = [x for x in comma_split_reviews if has_alpha(x) and len(x) >= 5]

# %%
len(reviews)
# Out:
# 10601

# %% [markdown]
# ### Токенизируем: с нормализацией и без

# %%
from collections import defaultdict
import matplotlib.pyplot as plt
import math
import numpy as np

# %%
import string
from nltk.tokenize import WhitespaceTokenizer, WordPunctTokenizer, TreebankWordTokenizer
from nltk.corpus import stopwords

stop_words = stopwords.words('russian')
stop_words.extend([x for x in string.punctuation] + ["«", "»", "это", "!", "!!", "!!!", "??"])
stop_words.remove("только")

# %%
import pymorphy2
morph = pymorphy2.MorphAnalyzer()

def normalize(x):
    return morph.parse(x)[0].normal_form

def extract_POS(x):
    return morph.parse(x)[0].tag.POS or "None"

# %%
tokenized_reviews = []
normalized_reviews = []

for r in reviews:
    tokens = [x for x in WordPunctTokenizer().tokenize(r) if x not in stop_words]
    tokens = [x for x in tokens if has_alpha(x)]
    tokenized_reviews.append(tokens)
    normalized_reviews.append([normalize(x) for x in tokens])

# %%
plt.figure(figsize=(16, 8))
plt.hist([len(x) for x in tokenized_reviews], bins=np.arange(0, 130, 2), rwidth=1)
plt.grid()
plt.title("Количество слов в отзыве (после очистки от стоп-слов)")
plt.xticks(np.arange(0, 130, 10))
plt.show()

# %%
POS_arr = []
for r in tokenized_reviews:
    POS_arr += [extract_POS(x) for x in r]

# %%
pos_counter = Counter(POS_arr)

# %%
ntop = len(pos_counter)
xs = np.arange(len(pos_counter))
ys = [y for x, y in pos_counter.most_common(ntop)][::-1]
labels = [x for x, y in pos_counter.most_common(ntop)][::-1]

plt.figure(figsize=(16, 8))
plt.title("Распределение слов по частям речи")

plt.barh(xs, ys)
plt.yticks(xs, labels=[x + "" for x in labels])
plt.ylabel("Labels")
plt.show()

# %% [markdown]
# Расшифровка тэгов:
# https://pymorphy2.readthedocs.io/en/stable/user/grammemes.html#grammeme-docs

# %% [markdown]
# ### Считаем частоты  n-грамм

# %%
def make_n_grams(arr, n, sep=" "):
    return [sep.join(arr[i:i+n]) for i in range(len(arr) - min(len(arr), n) + 1)]

# %%
N = 4

# %%
n_grams = defaultdict(list)
for tokens in tokenized_reviews:
    for i in range(1, N + 1):
        if len(tokens) >= i:
            n_grams[i] += make_n_grams(tokens, i)

# %%
counters = {}
for key, value in n_grams.items():
    counters[key] = Counter(value)

# %%
import pandas as pd

# %%
data = []
for key in counters.keys():
    for x, y in counters[key].items():
        data.append([key, x, y])
        
db = pd.DataFrame(data=data, columns=["ngram_len", "ngram", "cnt"])

# %%
db = db.sort_values(by=["ngram_len", "cnt"], ascending=[True, False], ignore_index=True)

# %%
db
# Out:
#         ngram_len                                 ngram   cnt
# 0               1                            приложение  2220
# 1               1                               сдавать  1445
# 2               1                                  кому  1379
# 3               1                                только  1229
# 4               1                              квартиру  1025
# ...           ...                                   ...   ...
# 145274          4  проблему портите репутацию ущемляете     1
# 145275          4  портите репутацию ущемляете интересы     1
# 145276          4  репутацию ущемляете интересы граждан     1
# 145277          4     ущемляете интересы граждан страны     1
# 145278          4        попытку скрыть проблемы страны     1
#
# [145279 rows x 3 columns]

# %%
db.to_csv("ngrams.csv")

# %%
ncols = 1
nrows = math.ceil(N / ncols)
ntop = 30

fig, axs = plt.subplots(figsize=(10 * ncols, 10 * nrows), ncols=ncols, nrows=nrows)

keys = []

for i, key in enumerate(counters.keys()):
    ax = axs.reshape(-1)[i]
    xs = np.arange(ntop)
    ys = [y for x, y in counters[key].most_common(ntop)][::-1]
    labels = [x for x, y in counters[key].most_common(ntop)][::-1]
    ax.grid()
    ax.barh(xs, ys)
    ax.set_yticks(xs)
    ax.set_yticklabels(labels, rotation=0)
    ax.set_xlabel("N-Grams count: {}".format(sum([value for value in counters[key].values()])))
    for x, y in zip(xs, ys):
        ax.annotate(str(y), xy=(y, x), xytext=(y + 0.1, x - 0.3))

plt.show()

# %% [markdown]
# ### То же самое, но с нормализацией

# %%
n_grams = defaultdict(list)
for tokens in normalized_reviews:
    for i in range(1, N + 1):
        if len(tokens) >= i:
            n_grams[i] += make_n_grams(tokens, i)

# %%
counters = {}
for key, value in n_grams.items():
    counters[key] = Counter(value)

# %%
data = []
for key in counters.keys():
    for x, y in counters[key].items():
        data.append([key, x, y])
        
db = pd.DataFrame(data=data, columns=["ngram_len", "ngram", "cnt"])
db = db.sort_values(by=["ngram_len", "cnt"], ascending=[True, False], ignore_index=True)
db.to_csv("normalized_ngrams.csv")

# %%
ncols = 1
nrows = math.ceil(N / ncols)
ntop = 30

fig, axs = plt.subplots(figsize=(10 * ncols, 10 * nrows), ncols=ncols, nrows=nrows)

keys = []

for i, key in enumerate(counters.keys()):
    ax = axs.reshape(-1)[i]
    xs = np.arange(ntop)
    ys = [y for x, y in counters[key].most_common(ntop)][::-1]
    labels = [x for x, y in counters[key].most_common(ntop)][::-1]
    ax.grid()
    ax.barh(xs, ys)
    ax.set_yticks(xs)
    ax.set_yticklabels(labels, rotation=0)
    ax.set_xlabel("N-Grams count: {}".format(sum([value for value in counters[key].values()])))
    for x, y in zip(xs, ys):
        ax.annotate(str(y), xy=(y, x), xytext=(y + 0.1, x - 0.3))

plt.show()

# %% [markdown]
# ## Некоторые примеры

# %%
examples = [
    "славянин славянин",
    "дискриминация славянин дискриминация славянин",
]

dct = {x:[] for x in examples}

for i, x in enumerate(normalized_reviews):
    key = " ".join(x)
    if key in examples:
        dct[key].append(reviews[i])
        
for key, value in dct.items():
    print(key)
    for x in value:
        print("\t- " + x)
    print("---")
# Out:
# славянин славянин
# ---
# дискриминация славянин дискриминация славянин
# ---

# %% [markdown]
# ## Word Embeddings

# %%
import gensim.downloader

# %%
list(gensim.downloader.info()['models'].keys())
# Out:
# ['fasttext-wiki-news-subwords-300',
#  'conceptnet-numberbatch-17-06-300',
#  'word2vec-ruscorpora-300',
#  'word2vec-google-news-300',
#  'glove-wiki-gigaword-50',
#  'glove-wiki-gigaword-100',
#  'glove-wiki-gigaword-200',
#  'glove-wiki-gigaword-300',
#  'glove-twitter-25',
#  'glove-twitter-50',
#  'glove-twitter-100',
#  'glove-twitter-200',
#  '__testing_word2vec-matrix-synopsis']

# %%
word_embeddings = gensim.downloader.load("word2vec-ruscorpora-300")

# %%
def review2vec(review, model):
    res = np.zeros(300)
    cnt = 0
    for word in review:
        pos = extract_POS(word)
        key = word + "_" + pos
        if key in model:
            res += model[key]
            cnt += 1
    return res / max(cnt, 1)

# %%
w2v_reviews = []
for r in normalized_reviews:
    w2v_reviews.append(review2vec(r, word_embeddings))

# %%
w2v_reviews = np.array(w2v_reviews)
w2v_reviews.shape
# Out:
# (10601, 300)

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=2)
pca_words = pca.fit_transform(w2v_reviews)

# %%
plt.scatter(pca_words[:, 0], pca_words[:, 1])
plt.title("Embeddings PCA")
plt.show()

# %%
from sklearn.cluster import DBSCAN, KMeans

# %%
eps = 5e-2
min_samples = 20

db = DBSCAN(eps=eps, metric="euclidean", min_samples=min_samples).fit(w2v_reviews)

labels = db.labels_
len(set(labels))
# Out:
# 29

# %%
words = np.array(reviews)
normed_words = np.array([" ".join(x) for x in normalized_reviews])

clusters = {}
normed_clusters = {}
sizes = {}
for label in set(labels):
    cluster = words[labels == label]
    normed_cluster = normed_words[labels == label]
    sizes[label] = len(cluster)
    clusters[label] = cluster
    normed_clusters[label] = normed_cluster
    
sizes_list = np.array(sorted([(x, y) for x,y in sizes.items()], key=lambda x: x[1], reverse=True))

plt.title("Cluster sizes")
plt.bar(sizes_list[:, 0], sizes_list[:, 1])
plt.show()

# %%
plt.figure(figsize=(10, 10))
for i in set(labels):
    s, a = (2, 1) if i != -1 else (0.1, 0.5)
    label = "{} : {}".format(i, sum(labels == i)) # if i != -1 else ""
    plt.scatter(
        pca_words[labels == i, 0], 
        pca_words[labels == i, 1],
        s=s,
        alpha=a,
        label=label)
plt.legend(loc=5)
plt.title("DBSCAN eps:{} min_samples:{} - Embeddings PCA".format(eps, min_samples))
plt.show()

# %%
n_top_clusters_to_plot = 1

sizes_to_plot = sizes_list[n_top_clusters_to_plot:, ]
sizes_to_plot = sizes_to_plot[sizes_to_plot[:, 1] > min_samples]

print("{} clusters cover {} reviews from {}".format(
    sizes_to_plot.shape[0],
    sum(sizes_to_plot[:, 1]),
    words.shape[0]
))
# Out:
# 25 clusters cover 3550 reviews from 10601

# %%
n_top_clusters_to_plot = 0

sizes_to_plot = sizes_list[n_top_clusters_to_plot:, ]
sizes_to_plot = sizes_to_plot[sizes_to_plot[:, 1] > min_samples]

print("{} clusters cover {} reviews from {}".format(
    sizes_to_plot.shape[0],
    sum(sizes_to_plot[:, 1]),
    words.shape[0]
))
# Out:
# 26 clusters cover 10541 reviews from 10601

# %%
n_examples = 15

for x in sizes_to_plot:
    print("Label {}, Cluster size: {}".format(x[0], x[1]))
    for review, normed_review in zip(clusters[x[0]][:n_examples], normed_clusters[x[0]][:n_examples]):
        print("\t- " + review) #+ " /\n\t\t (" + normed_review + ")")
    print("\n")
# Out:
# Label -1, Cluster size: 6991
# 	- обнаглевшие риелторы при содействии администрация блочат объявления частников вместо совершенствования оболочки компания тратит силы играя с пользователями в толерастию
# 	- отвратительный дизайн интерфейсов много старых объявлений тех поддержка никогда не отвечает не рекомендую
# 	- приложение лагает очень маленькая база по выбору другие агрегаторы дают больше выбора
# 	- надеюсь акции этой компании обвалятся а сама она обанкротится циан проводит очень подлую политику
# 	- два раза удалили отзыв молодцы так держать всеровно ваш сервис дрянь одни риелторы выходят на связь
# 	- не брат ты мне
# 	- подменные номера непонятная система отзывов и жалоб на объявления интеграция базы с фнс а теперь  еще и свое виденье того кто что как и кому может и не может снимать все свои объявления и уходить на альтернативные площадки а циан  в свободное эротическое плаванье
# 	- ужасное приложение как и компания в целом никому не советую
# 	- очень много не рабочих объявлений висит
# 	- молодцы что начали бороться с этой националистической гнилью уверен что и другие пойдут по вашим стопам но вы по любому молодцы потому что первые
# 	- лаги и тормоза вылетает когда открывается новое объявление нереально пользоваться куча риэлтороаперекупов
# 	- циан цензура до добра не доведёт поэтому
# 	- отвратительно все очень и очень плохо куча ложных объявлений  агенты и риелторы не качайте эту помойку ни в коем случае и не пользуйтесь можно было бы поставить меньше поставил бы
# 	- должен признаться не ожидал что у нас столько нацистов спасибо за ваше приложение и вполне адекватные решения
# 	- отзывы удаляются хотя было написано всё по существу
#
#
# Label 2, Cluster size: 1380
# 	- отстойное удаляю
# 	- удаляют оценкутретий раз
# 	- english
# 	- плохо
# 	- зависает
# 	- отвратительно
# 	- великолепно спасибо
# 	- сдавайте сами кому хотите
# 	- не рекомендую
# 	- отвратительное приложениепрощаемся
# 	- собирает личные данные
# 	- лагаетерунда полная
# 	- стало вообще дноне кому не рекомендую
# 	- отлично
# 	- всем хейтрам назло
#
#
# Label 3, Cluster size: 615
# 	- приложение ужасно лагает
# 	- очень удобное приложение
# 	- не информативное и не удобное приложение
# 	- ужасное приложение
# 	- отвратительное приложение
# 	- приложение классное всегда можно на него надеяться и найти то что тебе нужно спасибо
# 	- приложение глючит
# 	- приложение тормозит
# 	- отвратительное приложение
# 	- ужасное приложение
# 	- неудобное приложение
# 	- очень плохое приложение
# 	- неудобное приложение тормазит
# 	- не понравилось приложение неудобно пользоваться
# 	- очень хорошее приложение
#
#
# Label 6, Cluster size: 534
# 	- только славянам
# 	- хочется сдавать только славянам
# 	- дискриминируют славян
# 	- пятерки только славянам
# 	- только для славян
# 	- только для славян
# 	- за славян
# 	- только для славян
# 	- за славян
# 	- только для славян
# 	- омно полное сдаю только славянам
# 	- только славянам
# 	- сдам только славянам
# 	- дискриминаторы славян
# 	- буду сдавать только славянам
#
#
# Label 4, Cluster size: 139
# 	- дискриминация славян
# 	- дискриминация славян
# 	- дискриминация славян не рекомендую
# 	- что за дискриминация славян совсем уже установил сразу удаляю
# 	- дискриминация славян
# 	- дискриминация славян
# 	- дискриминация славян
# 	- дискриминация славян
# 	- против дискриминации славян
# 	- против дискриминации славян
# 	- я против дискриминации славян
# 	- кому хочу тому и буду сдавать  дискриминация славян
# 	- дискриминация славян
# 	- занимаются дискриминацией славян
# 	- дискриминация славян
#
#
# Label 8, Cluster size: 136
# 	- что хочу то и делаю со своей квартирой что хочу то и говорю
# 	- не хочу и не буду сдавать черным квартиру
# 	- я никогда не сдам квартиру кавказцаммусору из сразии
# 	- кому хочу тем и буду сдавать сами сдавайте свои квартиры кому хотите
# 	- запрещают сдавать квартиру кому я хочу
# 	- подобрали неадекватов в мою квартиру
# 	- почему за меня решают кому я должен сдавать квартиру
# 	- кому хочу сдаю квартиру
# 	- мы будем сдавать квартиры тем кому захотим
# 	- почему ктото за меня должен решать кому я буду сдавать квартиру
# 	- я сам решаю кому мне сдавать квартиру
# 	- я не хочу чтобы в моей квартире жили не русские
# 	- хочу сдавать квартиру только русским
# 	- кому хочу тем и сдаю квартиру вас это не должно волновать
# 	- я сам буду решать кому сдавать свою квартиру толерасты хреновы
#
#
# Label 10, Cluster size: 94
# 	- дискриминация
# 	- частная дискриминация это нормально
# 	- дискриминация русских
# 	- дискриминация
# 	- не рекомендую что за дискриминация
# 	- что за дискриминация русских
# 	- дискриминация
# 	- дискриминация русских
# 	- дискриминация русских
# 	- дискриминации
# 	- дискриминация русских
# 	- дискриминация рулит
# 	- дискриминация русских
# 	- дискриминация
# 	- дискриминация русских
#
#
# Label 9, Cluster size: 71
# 	- отвратительный сервис
# 	- отвратительный сервис
# 	- не понимаю кто пользуется данным сервисом если есть привычный avito
# 	- ужасный сервис
# 	- самый худший сервис
# 	- плохой сервис
# 	- очень неудобный сервис
# 	- самый неудобный сервис которым я пользовался постоянно глючит и зависает не рекомендую буду удалять
# 	- прекрасный сервис спасибо
# 	- так себе сервис
# 	- отвратительный сервис
# 	- ужасный просто ужасный сервис
# 	- не пользуйтесь этим сервисом
# 	- чернильный сервис
# 	- отличный сервис нашёл что искал
#
#
# Label 23, Cluster size: 64
# 	- русофобы вообще непонятно на кого работают
# 	- русофобы
# 	- русофобы
# 	- русофобы
# 	- русофобы
# 	- русофобы обнаглевшие теперь они за нас хотят решать кому сдавать кому не сдавать кому продавать а кому не продавать
# 	- русофобы
# 	- русофобы
# 	- русофобы
# 	- русофобы
# 	- русофобы
# 	- русофобы
# 	- русофобы
# 	- русофобы
# 	- русофобы
#
#
# Label 19, Cluster size: 44
# 	- не дают сдать квартиру бедным славянам  только биратам разрешают
# 	- хочу сдавать квартиру только славянам
# 	- я русский и хочу сдавать квартиру только славянам
# 	- нельзя сдать квартиру славянам
# 	- хочу здавать квартиру только славянам
# 	- квартиры для славян
# 	- хочу сдавать квартиру славянам
# 	- я русский и хочу сдавать квартиру только славянам
# 	- хочу сдавать квартиру славянам
# 	- нельзя сдавать сдавать квартиру только славянам
# 	- хочу сдавать квартиру только славянам
# 	- неудобно дорого нельзя сдавать квартиру славянам
# 	- это моя квартира и я сам буду решать сдавать ее славянам или нет
# 	- я узбэк верните пожалуйста квартиры славянам неудобна
# 	- жаль что нельзя сдавать квартиры только славянам
#
#
# Label 5, Cluster size: 41
# 	- недостоверные объявления
# 	- пользовался не понравилось слишком много левых объявлений иногда лагает
# 	- плохо работает постоянно вылетает и тормозит нельзя разместить нормальное объявление
# 	- нет реальных объявлений
# 	- я хочу писать в объявлении только то что надо мне
# 	- очень много фейковых объявлений пользуйтесь лучше чемнибудь другим
# 	- много лживых объявлений
# 	- удалили объявление теперь понял почему
# 	- работает медленно много левых объявлений
# 	- много лживых объявлений
# 	- я хочу писать в объявлении только то что надо мне
# 	- очень много фейковых объявлений пользуйтесь лучше чемнибудь другим
# 	- сплошные фейковые объявления
# 	- одни фейковые объявления
# 	- выскакивают объявления квартиркоторые уже проданы
#
#
# Label 13, Cluster size: 39
# 	- циан дорого и уже не сильно безопасно
# 	- не навижу  циан
# 	- циан днодаже объяснять не надовсекто действительно пользуется этим приложениемподтвердят перехожу на  авито
# 	- циан скатился удалено
# 	- циан гавно
# 	- no racism  спасибо циан дальше больше
# 	- циан скатился удалено
# 	- прощай циан
# 	- циан это вы зря
# 	- против циан
# 	- почему циан за меня решает я уже скачиваю авито
# 	- ненавижубл циан
# 	- сдам циан только для цыганей
# 	- циан ты худший
# 	- куда катится циан
#
#
# Label 24, Cluster size: 39
# 	- славянам в этом приложении делать нечего
# 	- приложение унижает славян
# 	- приложение полное г это я как славянин говорю
# 	- кому сдавать это мне решать и да только славянам удаляю приложение
# 	- это вам от славян удаляю ваше приложение
# 	- отличное приложение и всегда можно выбрать для славян
# 	- славяне больше не используют данное приложение
# 	- ваше приложение дискриминирует славян
# 	- приложения не для славян извините
# 	- плохое приложение славянин
# 	- приложение только для славян
# 	- неудобное приложение нельзя выбрать славян
# 	- скачал приложении а потом понял что я славянин а там нельзя такого
# 	- тормознутое приложение и зря вы задели славян
# 	- удаляю приложение от славян
#
#
# Label 0, Cluster size: 35
# 	- помойка
# 	- конченая помойка
# 	- толератная помойка
# 	- помойка
# 	- помойка
# 	- нучто тут скажешьлевацкая помойка
# 	- помойка
# 	- помойка
# 	- левацкая либеральная помойка
# 	- отвратительная помойка
# 	- толерантная помойка
# 	- отвратительная помойка
# 	- помойка
# 	- помойка
# 	- помойка
#
#
# Label 11, Cluster size: 35
# 	- удаляют отзывы
# 	- вы что отзывы удаляете
# 	- удаляют отзывы вы там что в себя поверили
# 	- почему отзывы уделяете
# 	- почему стираете негативные отзывы
# 	- почему отзывы уделяете
# 	- где мой отзыв удалили  что за х
# 	- чиститят отзывы
# 	- зачем удалили мой отзыв повторно
# 	- уже более  раз удалили мой отзыв  но я не сдаюсь
# 	- как здоворово чоо удаляете отзывы
# 	- удаляют отзывы
# 	- хватит удалять отзывы
# 	- мало тогочто дескриминируют людейтак ещё и отзывы удаляют
# 	- удаляют отзыв в  раз
#
#
# Label 20, Cluster size: 33
# 	- спасибо за обновление
# 	- плохое обновление
# 	- последние обновления просто ужасвы худшие
# 	- так себе обновление удаляю
# 	- сильно тормозит на oneplus  раньше такого не было только с последним обновлением разберитесь пожалуйста
# 	- все хуже и хуже особенно последнее обновление
# 	- зависает после последнего обновления
# 	- ужасное обновление
# 	- ужасное обновление
# 	- дизлайк за обновления
# 	- ужасное приложениепоследнее обновление убило напроч
# 	- тормозит лагает  с последними обновлениями стало только хуже
# 	- после последнего обновления стало жутко тупить пользоваться невозможно
# 	- после обновления все глючит
# 	- последнее обновление супер
#
#
# Label 22, Cluster size: 30
# 	- россия для русских
# 	- россия для русских
# 	- россия вперёд
# 	- ибо в россии
# 	- россия для русских
# 	- россия для русских
# 	- вы закроетесь в россии
# 	- россия для
# 	- россия для русских
# 	- россия для русских
# 	- очень печально видеть как много мдаков живет в россии круто что иногда встречаются такие как вы
# 	- россия для русских
# 	- россия для русских
# 	- россия для русских
# 	- россия для русских
#
#
# Label 16, Cluster size: 29
# 	- звезда и неболее
# 	- думаю вы прекрасно знаете за что одна звезда
# 	- заслужили  звезду толерантные
# 	- ахахахах  звезды
# 	- из  не рекомендую  звезда потому что  поставить не дают
# 	- ахахахах  звезды
# 	- из  не рекомендую  звезда потому что  поставить не дают
# 	- и на одну звезду не тянет
# 	- поставлю  звёзд только сами знаете кому
# 	- одна звезда сами понимаете все
# 	- ловите одну звезду много берете на себя
# 	- все знают почему  звезда
# 	- скачал чтобы поставить одну звезду
# 	- звезда ну сами знаете за что
# 	- одна звезда за вы знаете почему
#
#
# Label 1, Cluster size: 27
# 	- сдавать по своим правилам
# 	- странные правила что за талерантность к тем кто максимально не талерантен
# 	- против новых правил
# 	- правила меняйте
# 	- шагает тормозит странные правила
# 	- правила меняйте
# 	- странные правила что за талерантность к тем кто максимально не талерантен
# 	- шагает тормозит странные правила
# 	- против новых правил
# 	- правила глупые
# 	- за новые правила
# 	- глючит и правила мне нравятся удалю
# 	- новые правила для меня неприемлимы удаляю
# 	- этические правила для славянотрицательны
# 	- и правила новые убогие
#
#
# Label 7, Cluster size: 25
# 	- расисты бессовестные
# 	- расисты
# 	- расисты
# 	- разрабы расисты
# 	- расисты
# 	- расисты
# 	- расисты вы цыан
# 	- зашёл поддержать назло расистам
# 	- расисты какие то
# 	- разрабы дикие расисты
# 	- расисты
# 	- расисты
# 	- зачем вы ограничиваете расистов
# 	- расисты
# 	- расисты
#
#
# Label 21, Cluster size: 25
# 	- не имеете право указывать как и кому мне сдавать свою квартиру
# 	- моя квартира  моё право
# 	- ущемляют моё право выбирать кому я хочу и не хочу сдавать квартиру
# 	- моя квартира кому хочу тому и буду сдавать моё право
# 	- ущемляют моё право выбирать кому я хочу и не хочу сдавать квартиру
# 	- я русский и желаю сдавать свою квартиру русским и это мое полное право
# 	- что дальше принудительно обяжете заселять всех подряд квартира моя кому хочу тому и сдаю имею право
# 	- я сам в праве решить кому я буду сдавать свою квартиру а кому нет
# 	- я имею право сдавать свою квартиру кому захочу
# 	- каждый сам в праве решать кому сдавать свою квартиру
# 	- какое право вы имеете сдавать квартиры всем
# 	- какое имеете право указывать кому сдавать квартиру
# 	- только я в праве решать кому сдавать свою квартиру а кому нет
# 	- кому и как я буду сдавать квартиру  моё право
# 	- никто не имеет права мне указывать кому мне сдавать квартиру псевдотолерантные
#
#
# Label 27, Cluster size: 25
# 	- звезда из  за славян
# 	- оставшиеся звёзды доступны исключительно славянам
# 	- поставлю  звезд только славянам
# 	- ставлю  звёзд только для славян
# 	- ставлю пять звёзд только славянам
# 	- извините  звезд только для славян
# 	- сдаю  звезд только славянам
# 	- ставлю  звезд только славянам
# 	- звезду вам за славян
# 	- ставлю  звёзд только славянам
# 	- ставлю пять звёзд только славянам
# 	- звезд только славянам
# 	- одна звезда от славянина
# 	- не славянам нельзя указывать ловите  звезду
# 	- звёзд только славянам ставлю извините
#
#
# Label 12, Cluster size: 23
# 	- засуньте свою толерантность себе поглубже
# 	- хотели в толерантность а вот теперь пошли на йух
# 	- доигрались в толерантность
# 	- начитались про толерантность
# 	- доигрались в толерантность
# 	- толерантность у нас на принята
# 	- за толерантность
# 	- прекратите навязывать вашу толерантность скоро будете разрешать сдавать жильё только разнонацоналам
# 	- за толерантность
# 	- нет толерантности
# 	- у нас нет толерантности
# 	- толерантность не ваш конёк
# 	- дальше бейтесь за толерантность
# 	- за толерантность
# 	- не нужно навязывать нам псевдо толерантность
#
#
# Label 14, Cluster size: 23
# 	- слава роду
# 	- слава роду
# 	- слава роду
# 	- за славу
# 	- слава роду славянскому
# 	- слава роду славянскому
# 	- слава роду
# 	- слава славянскому роду
# 	- роду слава
# 	- слава роду славянскому
# 	- слава роду славянскому
# 	- слава роду славянскому
# 	- слава роду славянскому  плотная всем нашим
# 	- слава роду
# 	- слава роду
#
#
# Label 25, Cluster size: 23
# 	- полный отстой
# 	- отстой
# 	- отстой
# 	- полный отстой неудобно пользоваться
# 	- отстой
# 	- полный отстой
# 	- да просто полный отстой
# 	- отстой
# 	- не удобно и не информативно отстой
# 	- отстой
# 	- полный отстой
# 	- отстой
# 	- отстой
# 	- отстой
# 	- отстой
#
#
# Label 15, Cluster size: 21
# 	- я буду сдавать свою квартиру только русским уже без этого приложения
# 	- квартира моя и мне решать кому ее сдавать удаляю приложение
# 	- приложение хорошее  но это моя квартира и мне решать  кому её сдавать  а кому нет
# 	- отвратительное приложение указывает кому сдавать квартиру совсем обнаглели
# 	- ужасное приложение сдам квартиру только русским
# 	- ничего не понятно в приложении  как квартиру сдать русским
# 	- через это приложение нельзя сдавать квартиру только славянамизвинитесь за это
# 	- отвратительное приложение сдаю квартиру кому хочу кому не хочу  не сдаю
# 	- очень плохое приложение снять квартиру невозможно
# 	- самое уогое приложение из которых сдаёт квартиры
# 	- самое худшее приложение скачал и разачарован  много подставных квартир
# 	- отвратительное приложение сдаю квартиру кому хочу кому не хочу  не сдаю
# 	- не удобное приложение очень сложно найти квартиру совсем не юзабельное
# 	- очень плохо работает приложение вынуждает сдавать квартиры тем кому не хочешь
# 	- очень плохое приложение снять квартиру невозможно

# %%
data = []

for x in sizes_to_plot:
    label = x[0]
    cluster_size = x[1]
    for review, normed_review in zip(clusters[label], normed_clusters[label]):
        data.append([label, cluster_size, review, normed_review])
        
        
db = pd.DataFrame(data=data, columns=["cluster_label", "cluster_size", "review", "normed_review"])
db.to_csv("../processed_data/big_sample/later_reviews_clustered_1w_cluster_params_v2.csv")
